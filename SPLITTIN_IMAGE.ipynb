# %%
#METHOD-1: PATCHES CREATED ON TERMINAL

# %%
# !git clone https://github.com/niazwazir/TESTING_IMAGES.git
# Out:
# Cloning into 'TESTING_IMAGES'...
# remote: Enumerating objects: 49, done.
# remote: Counting objects: 100% (49/49), done.
# remote: Compressing objects: 100% (47/47), done.
# remote: Total 49 (delta 10), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (49/49), 25.60 MiB | 15.36 MiB/s, done.

# %%
cd TESTING_IMAGES/
# Out:
# /content/TESTING_IMAGES

# %%
# !ls
# Out:
# baby_x2_bicubic.png  baby_x2_SRCNN.png	HR	       WAZIR_MODEL_IMAGES
# baby_x2_GT.png	     BUTTERFLY.png	SPLITTING.png

# %%
from IPython.display import Image
Image('SPLITTING.png')

# %%
#METHOD-2: PATCHES CREATED IN GOOGLE COLAB

# %%
# !pip install split-image
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !split-image baby_x2_GT.png	4 4 --output-dir NIAZ
# Out:
# Exporting image tile: NIAZ/baby_x2_GT_0.png
# Exporting image tile: NIAZ/baby_x2_GT_1.png
# Exporting image tile: NIAZ/baby_x2_GT_2.png
# Exporting image tile: NIAZ/baby_x2_GT_3.png
# Exporting image tile: NIAZ/baby_x2_GT_4.png
# Exporting image tile: NIAZ/baby_x2_GT_5.png
# Exporting image tile: NIAZ/baby_x2_GT_6.png
# Exporting image tile: NIAZ/baby_x2_GT_7.png
# Exporting image tile: NIAZ/baby_x2_GT_8.png
# Exporting image tile: NIAZ/baby_x2_GT_9.png
# Exporting image tile: NIAZ/baby_x2_GT_10.png
# Exporting image tile: NIAZ/baby_x2_GT_11.png
# Exporting image tile: NIAZ/baby_x2_GT_12.png
# Exporting image tile: NIAZ/baby_x2_GT_13.png
# Exporting image tile: NIAZ/baby_x2_GT_14.png
# Exporting image tile: NIAZ/baby_x2_GT_15.png
# Done!

# %%
# !ls
# Out:
# baby_x2_bicubic.png  baby_x2_SRCNN.png	HR    SPLITTING.png
# baby_x2_GT.png	     BUTTERFLY.png	NIAZ  WAZIR_MODEL_IMAGES

# %%
cd NIAZ
# Out:
# /content/TESTING_IMAGES/NIAZ

# %%
# !ls
# Out:
# baby_x2_GT_0.png   baby_x2_GT_13.png  baby_x2_GT_2.png	baby_x2_GT_6.png
# baby_x2_GT_10.png  baby_x2_GT_14.png  baby_x2_GT_3.png	baby_x2_GT_7.png
# baby_x2_GT_11.png  baby_x2_GT_15.png  baby_x2_GT_4.png	baby_x2_GT_8.png
# baby_x2_GT_12.png  baby_x2_GT_1.png   baby_x2_GT_5.png	baby_x2_GT_9.png

# %%
import glob
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

# %%
#HOW MANY IMAGES WANT TO DISPLAY
NUM_ROWS = 4
IMGs_IN_ROW = 4

# %%
images = []
for img_path in glob.glob('*.png'):
    images.append(mpimg.imread(img_path))
f, ax_arr = plt.subplots(NUM_ROWS, IMGs_IN_ROW, figsize=(8,12))

for j, row in enumerate(ax_arr):
    for i, ax in enumerate(row):
        ax.imshow(images[j*IMGs_IN_ROW+i])
        ax.set_title(f'image {j*IMGs_IN_ROW+i+1}')
plt.show()
