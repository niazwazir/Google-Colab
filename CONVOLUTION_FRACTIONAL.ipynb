# %%
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Activation
import keras.backend as K
from keras import optimizers
import numpy as np
import h5py
from keras.layers import Input,Dense,Convolution2D,Activation,MaxPooling2D,Flatten,merge
from keras.layers.merge import add
from keras.models import Model, load_model
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot
from keras.utils import plot_model
from keras.layers.convolutional import Deconv2D as Conv2DTranspose

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-832dfd04-ca67-44be-a1c0-2d7a284a21c4" name="files[]" multiple disabled />
#      <output id="result-832dfd04-ca67-44be-a1c0-2d7a284a21c4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving B.png to B.png

# %%
from IPython.display import Image
Image('B.png')

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-582fcf1e-eb6a-425a-b881-a680c588b059" name="files[]" multiple disabled />
#      <output id="result-582fcf1e-eb6a-425a-b881-a680c588b059">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving A.png to A.png

# %%
from IPython.display import Image
Image('A.png')

# %%
model = Sequential([
    Conv2D(10, kernel_size=(3,3), input_shape=(28,28,10), activation ='relu',padding='same', use_bias=False)
   
])
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 28, 28, 10)        900
# =================================================================
# Total params: 900
# Trainable params: 900
# Non-trainable params: 0
# _________________________________________________________________

# %%
SVG(model_to_dot(model, show_shapes=True).create(prog='dot', format='svg'))

# %%
model1 = Sequential([
    Conv2D(10, kernel_size=(2,2), input_shape=(28,28,10), activation ='relu',padding='same', use_bias=False),
    Conv2D(10, kernel_size=(2,2), activation ='relu',padding='same', use_bias=False),
   
])
model1.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 28, 28, 10)        400
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 28, 28, 10)        400
# =================================================================
# Total params: 800
# Trainable params: 800
# Non-trainable params: 0
# _________________________________________________________________

# %%
SVG(model_to_dot(model1, show_shapes=True).create(prog='dot', format='svg'))

# %%
model2 = Sequential([
    Conv2D(10, kernel_size=(3,3), input_shape=(28,28,10), activation ='relu',padding='same', use_bias=False)
   
])
model2.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 28, 28, 10)        900
# =================================================================
# Total params: 900
# Trainable params: 900
# Non-trainable params: 0
# _________________________________________________________________

# %%
SVG(model_to_dot(model1, show_shapes=True).create(prog='dot', format='svg'))

# %%
model3 = Sequential([
    Conv2D(10, kernel_size=(5,1), input_shape=(28,28,10), activation ='relu',padding='same', use_bias=False),
    Conv2D(10, kernel_size=(1,5), activation ='relu',padding='same', use_bias=False),
   
])
model3.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_17 (Conv2D)           (None, 28, 28, 10)        500
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 28, 28, 10)        500
# =================================================================
# Total params: 1,000
# Trainable params: 1,000
# Non-trainable params: 0
# _________________________________________________________________

# %%
SVG(model_to_dot(model3, show_shapes=True).create(prog='dot', format='svg'))

# %%
model2 = Sequential([
    Conv2D(10, kernel_size=(11,11), input_shape=(28,28,10), activation ='relu',padding='same', use_bias=False)
   
])
model2.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_10 (Conv2D)           (None, 28, 28, 10)        12100
# =================================================================
# Total params: 12,100
# Trainable params: 12,100
# Non-trainable params: 0
# _________________________________________________________________
