# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img1 = cv2.imread('Set5/obama.png')
img_cvt=cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
plt.imshow(img_cvt)
plt.grid(None)
plt.show()

# %%
#bilinear_img = cv2.resize(img,None, fx = 10, fy = 10, interpolation = cv2.INTER_LINEAR)
#near_img = cv2.resize(img,None, fx = 10, fy = 10, interpolation = cv2.INTER_NEAREST)
bicubic_img = cv2.resize(img_cvt,None, fx = 0.5, fy = 0.5, interpolation = cv2.INTER_CUBIC)

# %%
img_cvt1=cv2.cvtColor(bicubic_img, cv2.COLOR_BGR2RGB)
plt.imshow(img_cvt)


plt.grid(None)
plt.show()

# %%
print(img_cvt1.shape)
# Out:
# (210, 374, 3)

# %%
cv2.imshow('LR_IMAGE',img_cvt1)
cv2.waitKey(0)
cv2.destroyAllWindows()

cv2.imshow('BICUBIC UPSCALED IMAGEimage',img1)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#bilinear_img = cv2.resize(img,None, fx = 10, fy = 10, interpolation = cv2.INTER_LINEAR)
#near_img = cv2.resize(img,None, fx = 10, fy = 10, interpolation = cv2.INTER_NEAREST)
bicubic_img2 = cv2.resize(img_cvt1,None, fx = 2, fy = 2, interpolation = cv2.INTER_CUBIC)

# %%
cv2.imshow('image',bicubic_img2)
cv2.waitKey(0)
cv2.destroyAllWindows()
