# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-fadb98b8-7feb-45cf-8fdb-2733876fc7ca" name="files[]" multiple disabled />
#      <output id="result-fadb98b8-7feb-45cf-8fdb-2733876fc7ca">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving zebra.bmp to zebra.bmp

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv2.imread("zebra.bmp")
img_cvt=cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_cvt)
plt.grid(None)
plt.show()

# %%
print(img.shape)
# Out:
# (391, 586, 3)

# %%
plt.imshow(img)
plt.grid(None)

# %%
IMG_SIZE = 500
smallimg = cv2.resize(img,(IMG_SIZE,IMG_SIZE))
plt.imshow(smallimg,cmap="gray")
plt.grid(None)

# %%
print(smallimg.shape)
# Out:
# (500, 500, 3)
