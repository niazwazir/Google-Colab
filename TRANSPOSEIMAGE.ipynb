# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-61c7db80-a446-4bd7-bd3c-0e4c2b00929d" name="files[]" multiple disabled />
#      <output id="result-61c7db80-a446-4bd7-bd3c-0e4c2b00929d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving TRANSPOSEIMAGE.png to TRANSPOSEIMAGE.png

# %%
from IPython.display import Image
Image('TRANSPOSEIMAGE.png')

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

# %%
img_array = mpimg.imread('https://raw.githubusercontent.com/dmlc/web-data/master/mxnet/doc/tutorials/basic/transpose_reshape/cat.png')
plt.imshow(img_array)
plt.axis("off")
print (img_array.shape)
# Out:
# (157, 210, 3)

# %%
transposed = img_array.transpose((1,0,2))
plt.imshow(transposed)
plt.axis("off")
# Out:
# (-0.5, 156.5, 209.5, -0.5)
