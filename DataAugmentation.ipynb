# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import misc, ndimage
import keras
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
def plots(ims, figsize=(12,6), rows=1, interp=False, titles=None):
    if type(ims[0]) is np.ndarray:
        ims = np.array(ims).astype(np.uint8)
        if (ims.shape[-1] != 3):
          ims = ims.transpose((0,2,3,1))
    f = plt.figure(figsize=figsize)
    cols = len(ims)//rows if len(ims) % 2 == 0 else len(ims)//rows + 1
    
    for i in range(len(ims)):
        sp = f.add_subplot(rows, len(ims)//rows, i+1)
        sp.axis('Off')
        if titles is not None:
          sp.set_title(titles[i], fontsize=16)
        plt.imshow(ims[i], interpolation=None if interp else 'none')

# %%
gen = ImageDataGenerator(rotation_range=10, width_shift_range=0.1, height_shift_range=0.1, shear_range = 0.15, zoom_range = 0.1, channel_shift_range = 10,  horizontal_flip=True)

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3587f7f9-eddf-4018-aaba-ba4b1716f35f" name="files[]" multiple disabled />
#      <output id="result-3587f7f9-eddf-4018-aaba-ba4b1716f35f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Test.jpg to Test.jpg
# Saving Test1.png to Test1.png

# %%
image=np.expand_dims(ndimage.imread('Test1.png'),0)
plt.grid(None)
plt.imshow(image[0])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0.
# Use ``matplotlib.pyplot.imread`` instead.
#   """Entry point for launching an IPython kernel.

# %%
aug_iter = gen.flow(image)

# %%
aug_images = [next(aug_iter)[0].astype(np.uint8) for i in range(10)]

# %%
# Augmented images
plots(aug_images, figsize=(20,7), rows=2)

# %%
#HERE WE OBSERVED THE ARM OF BARBARA SHOWS IN DIFFERENT SOME TIME SHOW LEFT AND SOME TIME SHOW RIGHT'

# %%
image=np.expand_dims(ndimage.imread('Test.jpg'),0)
plt.grid(None)
plt.imshow(image[0])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0.
# Use ``matplotlib.pyplot.imread`` instead.
#   """Entry point for launching an IPython kernel.

# %%
aug_iter = gen.flow(image)

# %%
aug_images = [next(aug_iter)[0].astype(np.uint8) for i in range(10)]

# %%
# Augmented images
plots(aug_images, figsize=(20,7), rows=2)
