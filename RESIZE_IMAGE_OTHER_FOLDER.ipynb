# %%
# !ls
# Out:
# sample_data

# %%
# !git clone https://github.com/niazwazir/SET5_BMP.git
# Out:
# Cloning into 'SET5_BMP'...
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 7 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (7/7), done.

# %%
# !ls
# Out:
# sample_data  SET5_BMP

# %%
import cv2
import os, sys
import numpy as np
from PIL import Image
from matplotlib import pyplot as plt

# %%
img1 = cv2.imread("SET5_BMP/baby_GT.bmp")
img_cvt=cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
plt.imshow(img_cvt)
plt.show()

# %%
print(img1.shape)
# Out:
# (512, 512, 3)

# %%
# !mkdir RESIZESET5_BMP

# %%
# !ls
# Out:
# RESIZESET5_BMP	sample_data  SET5_BMP

# %%
path = "SET5_BMP/"
path1="RESIZESET5_BMP/"
dirs = os.listdir(path)

def resize():
    for item in dirs:
        if os.path.isfile(path+item):
            im = Image.open(path+item)
            f, e = os.path.splitext(path1+item)
            imResize = im.resize((128,128), Image.ANTIALIAS)
            imResize.save(f + 'resized.bmp', 'bmp', quality=90)

resize()

# %%
# !ls
# Out:
# RESIZESET5_BMP	sample_data  SET5_BMP

# %%
cd RESIZESET5_BMP
# Out:
# /content/RESIZESET5_BMP

# %%
# !ls
# Out:
# baby_GTresized.bmp  butterfly_GTresized.bmp  woman_GTresized.bmp
# bird_GTresized.bmp  head_GTresized.bmp

# %%
img2 = cv2.imread("baby_GTresized.bmp")
img_cvt=cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)
plt.imshow(img_cvt)
plt.show()

# %%
print(img2.shape)
# Out:
# (128, 128, 3)
