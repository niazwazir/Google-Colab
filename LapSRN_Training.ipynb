# %%
# !git clone https://github.com/twtygqyy/pytorch-LapSRN.git
# Out:
# Cloning into 'pytorch-LapSRN'...
# remote: Enumerating objects: 85, done.
# remote: Total 85 (delta 0), reused 0 (delta 0), pack-reused 85
# Unpacking objects: 100% (85/85), done.

# %%
# !ls
# Out:
# checkpoint  demo.py    lapsrn_wgan.py  main_lapwgan.py	README.md
# data	    eval.py    LICENSE	       model		Set5
# dataset.py  lapsrn.py  main_lapsrn.py  __pycache__	Test

# %%
cd pytorch-LapSRN/
# Out:
# [Errno 2] No such file or directory: 'pytorch-LapSRN/'
# /content/pytorch-LapSRN/pytorch-LapSRN

# %%
# !ls
# Out:
# checkpoint  demo.py    lapsrn_wgan.py  main_lapwgan.py	README.md
# data	    eval.py    LICENSE	       model		Set5
# dataset.py  lapsrn.py  main_lapsrn.py  __pycache__	Test

# %%
# !rm -f main_lapsrn.py

# %%
#upload main_lapsrn.py file with different epochs

# %%
from google.colab import files 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7827b509-30c5-4bf4-909d-3555a2871c40" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7827b509-30c5-4bf4-909d-3555a2871c40">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving main_lapsrn.py to main_lapsrn.py

# %%
# !python main_lapsrn.py --cuda
# Out:
# Namespace(batchSize=16, cuda=True, lr=0.0001, momentum=0.9, nEpochs=500, pretrained='', resume='', start_epoch=1, step=100, threads=1, weight_decay=0.0001)
# Random Seed:  4638
# ===> Loading datasets
# /content/pytorch-LapSRN/pytorch-LapSRN/dataset.py:9: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#   hf = h5py.File(file_path)
# ===> Building model
# ===> Setting GPU
# ===> Setting Optimizer
# ===> Training
# Epoch=1, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_1.pth
# Epoch=2, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_2.pth
# Epoch=3, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_3.pth
# Epoch=4, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_4.pth
# Epoch=5, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_5.pth
# Epoch=6, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_6.pth
# Epoch=7, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_7.pth
# Epoch=8, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_8.pth
# Epoch=9, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_9.pth
# Epoch=10, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_10.pth
# Epoch=11, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_11.pth
# Epoch=12, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_12.pth
# Epoch=13, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_13.pth
# Epoch=14, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_14.pth
# Epoch=15, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_15.pth
# Epoch=16, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_16.pth
# Epoch=17, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_17.pth
# Epoch=18, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_18.pth
# Epoch=19, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_19.pth
# Epoch=20, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_20.pth
# Epoch=21, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_21.pth
# Epoch=22, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_22.pth
# Epoch=23, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_23.pth
# Epoch=24, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_24.pth
# Epoch=25, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_25.pth
# Epoch=26, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_26.pth
# Epoch=27, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_27.pth
# Epoch=28, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_28.pth
# Epoch=29, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_29.pth
# Epoch=30, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_30.pth
# Epoch=31, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_31.pth
# Epoch=32, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_32.pth
# Epoch=33, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_33.pth
# Epoch=34, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_34.pth
# Epoch=35, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_35.pth
# Epoch=36, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_36.pth
# Epoch=37, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_37.pth
# Epoch=38, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_38.pth
# Epoch=39, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_39.pth
# Epoch=40, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_40.pth
# Epoch=41, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_41.pth
# Epoch=42, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_42.pth
# Epoch=43, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_43.pth
# Epoch=44, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_44.pth
# Epoch=45, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_45.pth
# Epoch=46, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_46.pth
# Epoch=47, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_47.pth
# Epoch=48, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_48.pth
# Epoch=49, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_49.pth
# Epoch=50, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_50.pth
# Epoch=51, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_51.pth
# Epoch=52, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_52.pth
# Epoch=53, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_53.pth
# Epoch=54, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_54.pth
# Epoch=55, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_55.pth
# Epoch=56, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_56.pth
# Epoch=57, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_57.pth
# Epoch=58, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_58.pth
# Epoch=59, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_59.pth
# Epoch=60, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_60.pth
# Epoch=61, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_61.pth
# Epoch=62, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_62.pth
# Epoch=63, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_63.pth
# Epoch=64, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_64.pth
# Epoch=65, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_65.pth
# Epoch=66, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_66.pth
# Epoch=67, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_67.pth
# Epoch=68, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_68.pth
# Epoch=69, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_69.pth
# Epoch=70, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_70.pth
# Epoch=71, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_71.pth
# Epoch=72, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_72.pth
# Epoch=73, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_73.pth
# Epoch=74, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_74.pth
# Epoch=75, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_75.pth
# Epoch=76, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_76.pth
# Epoch=77, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_77.pth
# Epoch=78, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_78.pth
# Epoch=79, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_79.pth
# Epoch=80, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_80.pth
# Epoch=81, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_81.pth
# Epoch=82, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_82.pth
# Epoch=83, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_83.pth
# Epoch=84, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_84.pth
# Epoch=85, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_85.pth
# Epoch=86, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_86.pth
# Epoch=87, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_87.pth
# Epoch=88, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_88.pth
# Epoch=89, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_89.pth
# Epoch=90, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_90.pth
# Epoch=91, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_91.pth
# Epoch=92, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_92.pth
# Epoch=93, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_93.pth
# Epoch=94, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_94.pth
# Epoch=95, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_95.pth
# Epoch=96, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_96.pth
# Epoch=97, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_97.pth
# Epoch=98, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_98.pth
# Epoch=99, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_99.pth
# Epoch=100, lr=0.0001
# Checkpoint saved to checkpoint/lapsrn_model_epoch_100.pth
# Epoch=101, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_101.pth
# Epoch=102, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_102.pth
# Epoch=103, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_103.pth
# Epoch=104, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_104.pth
# Epoch=105, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_105.pth
# Epoch=106, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_106.pth
# Epoch=107, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_107.pth
# Epoch=108, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_108.pth
# Epoch=109, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_109.pth
# Epoch=110, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_110.pth
# Epoch=111, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_111.pth
# Epoch=112, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_112.pth
# Epoch=113, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_113.pth
# Epoch=114, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_114.pth
# Epoch=115, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_115.pth
# Epoch=116, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_116.pth
# Epoch=117, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_117.pth
# Epoch=118, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_118.pth
# Epoch=119, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_119.pth
# Epoch=120, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_120.pth
# Epoch=121, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_121.pth
# Epoch=122, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_122.pth
# Epoch=123, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_123.pth
# Epoch=124, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_124.pth
# Epoch=125, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_125.pth
# Epoch=126, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_126.pth
# Epoch=127, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_127.pth
# Epoch=128, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_128.pth
# Epoch=129, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_129.pth
# Epoch=130, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_130.pth
# Epoch=131, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_131.pth
# Epoch=132, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_132.pth
# Epoch=133, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_133.pth
# Epoch=134, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_134.pth
# Epoch=135, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_135.pth
# Epoch=136, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_136.pth
# Epoch=137, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_137.pth
# Epoch=138, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_138.pth
# Epoch=139, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_139.pth
# Epoch=140, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_140.pth
# Epoch=141, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_141.pth
# Epoch=142, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_142.pth
# Epoch=143, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_143.pth
# Epoch=144, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_144.pth
# Epoch=145, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_145.pth
# Epoch=146, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_146.pth
# Epoch=147, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_147.pth
# Epoch=148, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_148.pth
# Epoch=149, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_149.pth
# Epoch=150, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_150.pth
# Epoch=151, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_151.pth
# Epoch=152, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_152.pth
# Epoch=153, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_153.pth
# Epoch=154, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_154.pth
# Epoch=155, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_155.pth
# Epoch=156, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_156.pth
# Epoch=157, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_157.pth
# Epoch=158, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_158.pth
# Epoch=159, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_159.pth
# Epoch=160, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_160.pth
# Epoch=161, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_161.pth
# Epoch=162, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_162.pth
# Epoch=163, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_163.pth
# Epoch=164, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_164.pth
# Epoch=165, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_165.pth
# Epoch=166, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_166.pth
# Epoch=167, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_167.pth
# Epoch=168, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_168.pth
# Epoch=169, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_169.pth
# Epoch=170, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_170.pth
# Epoch=171, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_171.pth
# Epoch=172, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_172.pth
# Epoch=173, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_173.pth
# Epoch=174, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_174.pth
# Epoch=175, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_175.pth
# Epoch=176, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_176.pth
# Epoch=177, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_177.pth
# Epoch=178, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_178.pth
# Epoch=179, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_179.pth
# Epoch=180, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_180.pth
# Epoch=181, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_181.pth
# Epoch=182, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_182.pth
# Epoch=183, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_183.pth
# Epoch=184, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_184.pth
# Epoch=185, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_185.pth
# Epoch=186, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_186.pth
# Epoch=187, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_187.pth
# Epoch=188, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_188.pth
# Epoch=189, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_189.pth
# Epoch=190, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_190.pth
# Epoch=191, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_191.pth
# Epoch=192, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_192.pth
# Epoch=193, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_193.pth
# Epoch=194, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_194.pth
# Epoch=195, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_195.pth
# Epoch=196, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_196.pth
# Epoch=197, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_197.pth
# Epoch=198, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_198.pth
# Epoch=199, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_199.pth
# Epoch=200, lr=1e-05
# Checkpoint saved to checkpoint/lapsrn_model_epoch_200.pth
# Epoch=201, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_201.pth
# Epoch=202, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_202.pth
# Epoch=203, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_203.pth
# Epoch=204, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_204.pth
# Epoch=205, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_205.pth
# Epoch=206, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_206.pth
# Epoch=207, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_207.pth
# Epoch=208, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_208.pth
# Epoch=209, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_209.pth
# Epoch=210, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_210.pth
# Epoch=211, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_211.pth
# Epoch=212, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_212.pth
# Epoch=213, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_213.pth
# Epoch=214, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_214.pth
# Epoch=215, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_215.pth
# Epoch=216, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_216.pth
# Epoch=217, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_217.pth
# Epoch=218, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_218.pth
# Epoch=219, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_219.pth
# Epoch=220, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_220.pth
# Epoch=221, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_221.pth
# Epoch=222, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_222.pth
# Epoch=223, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_223.pth
# Epoch=224, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_224.pth
# Epoch=225, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_225.pth
# Epoch=226, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_226.pth
# Epoch=227, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_227.pth
# Epoch=228, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_228.pth
# Epoch=229, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_229.pth
# Epoch=230, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_230.pth
# Epoch=231, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_231.pth
# Epoch=232, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_232.pth
# Epoch=233, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_233.pth
# Epoch=234, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_234.pth
# Epoch=235, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_235.pth
# Epoch=236, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_236.pth
# Epoch=237, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_237.pth
# Epoch=238, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_238.pth
# Epoch=239, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_239.pth
# Epoch=240, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_240.pth
# Epoch=241, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_241.pth
# Epoch=242, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_242.pth
# Epoch=243, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_243.pth
# Epoch=244, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_244.pth
# Epoch=245, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_245.pth
# Epoch=246, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_246.pth
# Epoch=247, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_247.pth
# Epoch=248, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_248.pth
# Epoch=249, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_249.pth
# Epoch=250, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_250.pth
# Epoch=251, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_251.pth
# Epoch=252, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_252.pth
# Epoch=253, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_253.pth
# Epoch=254, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_254.pth
# Epoch=255, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_255.pth
# Epoch=256, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_256.pth
# Epoch=257, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_257.pth
# Epoch=258, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_258.pth
# Epoch=259, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_259.pth
# Epoch=260, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_260.pth
# Epoch=261, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_261.pth
# Epoch=262, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_262.pth
# Epoch=263, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_263.pth
# Epoch=264, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_264.pth
# Epoch=265, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_265.pth
# Epoch=266, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_266.pth
# Epoch=267, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_267.pth
# Epoch=268, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_268.pth
# Epoch=269, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_269.pth
# Epoch=270, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_270.pth
# Epoch=271, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_271.pth
# Epoch=272, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_272.pth
# Epoch=273, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_273.pth
# Epoch=274, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_274.pth
# Epoch=275, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_275.pth
# Epoch=276, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_276.pth
# Epoch=277, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_277.pth
# Epoch=278, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_278.pth
# Epoch=279, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_279.pth
# Epoch=280, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_280.pth
# Epoch=281, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_281.pth
# Epoch=282, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_282.pth
# Epoch=283, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_283.pth
# Epoch=284, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_284.pth
# Epoch=285, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_285.pth
# Epoch=286, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_286.pth
# Epoch=287, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_287.pth
# Epoch=288, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_288.pth
# Epoch=289, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_289.pth
# Epoch=290, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_290.pth
# Epoch=291, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_291.pth
# Epoch=292, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_292.pth
# Epoch=293, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_293.pth
# Epoch=294, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_294.pth
# Epoch=295, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_295.pth
# Epoch=296, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_296.pth
# Epoch=297, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_297.pth
# Epoch=298, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_298.pth
# Epoch=299, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_299.pth
# Epoch=300, lr=1.0000000000000002e-06
# Checkpoint saved to checkpoint/lapsrn_model_epoch_300.pth
# Epoch=301, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_301.pth
# Epoch=302, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_302.pth
# Epoch=303, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_303.pth
# Epoch=304, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_304.pth
# Epoch=305, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_305.pth
# Epoch=306, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_306.pth
# Epoch=307, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_307.pth
# Epoch=308, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_308.pth
# Epoch=309, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_309.pth
# Epoch=310, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_310.pth
# Epoch=311, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_311.pth
# Epoch=312, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_312.pth
# Epoch=313, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_313.pth
# Epoch=314, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_314.pth
# Epoch=315, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_315.pth
# Epoch=316, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_316.pth
# Epoch=317, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_317.pth
# Epoch=318, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_318.pth
# Epoch=319, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_319.pth
# Epoch=320, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_320.pth
# Epoch=321, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_321.pth
# Epoch=322, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_322.pth
# Epoch=323, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_323.pth
# Epoch=324, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_324.pth
# Epoch=325, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_325.pth
# Epoch=326, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_326.pth
# Epoch=327, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_327.pth
# Epoch=328, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_328.pth
# Epoch=329, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_329.pth
# Epoch=330, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_330.pth
# Epoch=331, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_331.pth
# Epoch=332, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_332.pth
# Epoch=333, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_333.pth
# Epoch=334, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_334.pth
# Epoch=335, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_335.pth
# Epoch=336, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_336.pth
# Epoch=337, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_337.pth
# Epoch=338, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_338.pth
# Epoch=339, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_339.pth
# Epoch=340, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_340.pth
# Epoch=341, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_341.pth
# Epoch=342, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_342.pth
# Epoch=343, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_343.pth
# Epoch=344, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_344.pth
# Epoch=345, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_345.pth
# Epoch=346, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_346.pth
# Epoch=347, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_347.pth
# Epoch=348, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_348.pth
# Epoch=349, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_349.pth
# Epoch=350, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_350.pth
# Epoch=351, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_351.pth
# Epoch=352, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_352.pth
# Epoch=353, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_353.pth
# Epoch=354, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_354.pth
# Epoch=355, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_355.pth
# Epoch=356, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_356.pth
# Epoch=357, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_357.pth
# Epoch=358, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_358.pth
# Epoch=359, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_359.pth
# Epoch=360, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_360.pth
# Epoch=361, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_361.pth
# Epoch=362, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_362.pth
# Epoch=363, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_363.pth
# Epoch=364, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_364.pth
# Epoch=365, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_365.pth
# Epoch=366, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_366.pth
# Epoch=367, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_367.pth
# Epoch=368, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_368.pth
# Epoch=369, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_369.pth
# Epoch=370, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_370.pth
# Epoch=371, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_371.pth
# Epoch=372, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_372.pth
# Epoch=373, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_373.pth
# Epoch=374, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_374.pth
# Epoch=375, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_375.pth
# Epoch=376, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_376.pth
# Epoch=377, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_377.pth
# Epoch=378, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_378.pth
# Epoch=379, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_379.pth
# Epoch=380, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_380.pth
# Epoch=381, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_381.pth
# Epoch=382, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_382.pth
# Epoch=383, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_383.pth
# Epoch=384, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_384.pth
# Epoch=385, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_385.pth
# Epoch=386, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_386.pth
# Epoch=387, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_387.pth
# Epoch=388, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_388.pth
# Epoch=389, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_389.pth
# Epoch=390, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_390.pth
# Epoch=391, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_391.pth
# Epoch=392, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_392.pth
# Epoch=393, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_393.pth
# Epoch=394, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_394.pth
# Epoch=395, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_395.pth
# Epoch=396, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_396.pth
# Epoch=397, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_397.pth
# Epoch=398, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_398.pth
# Epoch=399, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_399.pth
# Epoch=400, lr=1.0000000000000002e-07
# Checkpoint saved to checkpoint/lapsrn_model_epoch_400.pth
# Epoch=401, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_401.pth
# Epoch=402, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_402.pth
# Epoch=403, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_403.pth
# Epoch=404, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_404.pth
# Epoch=405, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_405.pth
# Epoch=406, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_406.pth
# Epoch=407, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_407.pth
# Epoch=408, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_408.pth
# Epoch=409, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_409.pth
# Epoch=410, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_410.pth
# Epoch=411, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_411.pth
# Epoch=412, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_412.pth
# Epoch=413, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_413.pth
# Epoch=414, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_414.pth
# Epoch=415, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_415.pth
# Epoch=416, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_416.pth
# Epoch=417, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_417.pth
# Epoch=418, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_418.pth
# Epoch=419, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_419.pth
# Epoch=420, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_420.pth
# Epoch=421, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_421.pth
# Epoch=422, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_422.pth
# Epoch=423, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_423.pth
# Epoch=424, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_424.pth
# Epoch=425, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_425.pth
# Epoch=426, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_426.pth
# Epoch=427, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_427.pth
# Epoch=428, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_428.pth
# Epoch=429, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_429.pth
# Epoch=430, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_430.pth
# Epoch=431, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_431.pth
# Epoch=432, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_432.pth
# Epoch=433, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_433.pth
# Epoch=434, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_434.pth
# Epoch=435, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_435.pth
# Epoch=436, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_436.pth
# Epoch=437, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_437.pth
# Epoch=438, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_438.pth
# Epoch=439, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_439.pth
# Epoch=440, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_440.pth
# Epoch=441, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_441.pth
# Epoch=442, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_442.pth
# Epoch=443, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_443.pth
# Epoch=444, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_444.pth
# Epoch=445, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_445.pth
# Epoch=446, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_446.pth
# Epoch=447, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_447.pth
# Epoch=448, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_448.pth
# Epoch=449, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_449.pth
# Epoch=450, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_450.pth
# Epoch=451, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_451.pth
# Epoch=452, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_452.pth
# Epoch=453, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_453.pth
# Epoch=454, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_454.pth
# Epoch=455, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_455.pth
# Epoch=456, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_456.pth
# Epoch=457, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_457.pth
# Epoch=458, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_458.pth
# Epoch=459, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_459.pth
# Epoch=460, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_460.pth
# Epoch=461, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_461.pth
# Epoch=462, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_462.pth
# Epoch=463, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_463.pth
# Epoch=464, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_464.pth
# Epoch=465, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_465.pth
# Epoch=466, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_466.pth
# Epoch=467, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_467.pth
# Epoch=468, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_468.pth
# Epoch=469, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_469.pth
# Epoch=470, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_470.pth
# Epoch=471, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_471.pth
# Epoch=472, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_472.pth
# Epoch=473, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_473.pth
# Epoch=474, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_474.pth
# Epoch=475, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_475.pth
# Epoch=476, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_476.pth
# Epoch=477, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_477.pth
# Epoch=478, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_478.pth
# Epoch=479, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_479.pth
# Epoch=480, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_480.pth
# Epoch=481, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_481.pth
# Epoch=482, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_482.pth
# Epoch=483, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_483.pth
# Epoch=484, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_484.pth
# Epoch=485, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_485.pth
# Epoch=486, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_486.pth
# Epoch=487, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_487.pth
# Epoch=488, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_488.pth
# Epoch=489, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_489.pth
# Epoch=490, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_490.pth
# Epoch=491, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_491.pth
# Epoch=492, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_492.pth
# Epoch=493, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_493.pth
# Epoch=494, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_494.pth
# Epoch=495, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_495.pth
# Epoch=496, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_496.pth
# Epoch=497, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_497.pth
# Epoch=498, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_498.pth
# Epoch=499, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_499.pth
# Epoch=500, lr=1.0000000000000002e-08
# Checkpoint saved to checkpoint/lapsrn_model_epoch_500.pth

# %%
# !rm -f eval.py

# %%
#UPLOAD eval.py

# %%
from google.colab import files 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6a4feda7-9c5e-40ee-b22d-c4647a95d8d9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6a4feda7-9c5e-40ee-b22d-c4647a95d8d9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving eval.py to eval.py

# %%
# !python eval.py
# Out:
# Processing  Set5/baby_GT.mat
# Processing  Set5/head_GT.mat
# Processing  Set5/woman_GT.mat
# Processing  Set5/butterfly_GT.mat
# Processing  Set5/bird_GT.mat
# Scale= 4
# Dataset= Set5
# PSNR_predicted= 28.456681551503
# PSNR_bicubic= 28.432432425785294
# It takes average 0.588666296005249s for processing

# %%
# !python eval.py
# Out:
# Processing  Set5/baby_GT.mat
# Processing  Set5/head_GT.mat
# Processing  Set5/woman_GT.mat
# Processing  Set5/butterfly_GT.mat
# Processing  Set5/bird_GT.mat
# Scale= 4
# Dataset= Set5
# PSNR_predicted= 28.73385763907251
# PSNR_bicubic= 28.432432425785294
# It takes average 0.5951828956604004s for processing

# %%
# !python eval.py
# Out:
# Processing  Set5/baby_GT.mat
# Processing  Set5/head_GT.mat
# Processing  Set5/woman_GT.mat
# Processing  Set5/butterfly_GT.mat
# Processing  Set5/bird_GT.mat
# Scale= 4
# Dataset= Set5
# PSNR_predicted= 28.620233353880888
# PSNR_bicubic= 28.432432425785294
# It takes average 0.5869547367095947s for processing

# %%
# !python eval.py
# Out:
# Processing  Set5/baby_GT.mat
# Processing  Set5/head_GT.mat
# Processing  Set5/woman_GT.mat
# Processing  Set5/butterfly_GT.mat
# Processing  Set5/bird_GT.mat
# Scale= 4
# Dataset= Set5
# PSNR_predicted= 27.687782751949374
# PSNR_bicubic= 28.432432425785294
# It takes average 0.541048812866211s for processing

# %%
# !python eval.py
# Out:
# Processing  Set5/baby_GT.mat
# Processing  Set5/head_GT.mat
# Processing  Set5/woman_GT.mat
# Processing  Set5/butterfly_GT.mat
# Processing  Set5/bird_GT.mat
# Scale= 4
# Dataset= Set5
# PSNR_predicted= 28.044371153947054
# PSNR_bicubic= 28.432432425785294
# It takes average 0.5276489734649659s for processing

# %%
# !python eval.py
# Out:
# Processing  Set5/baby_GT.mat
# Processing  Set5/head_GT.mat
# Processing  Set5/woman_GT.mat
# Processing  Set5/butterfly_GT.mat
# Processing  Set5/bird_GT.mat
# Scale= 4
# Dataset= Set5
# PSNR_predicted= 28.132713389916557
# PSNR_bicubic= 28.432432425785294
# It takes average 0.5299244880676269s for processing

# %%
# !python eval.py
