# %%
#UPLOAD IMAGE
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3f279244-e92d-4613-b275-a10c435b2bf8" name="files[]" multiple disabled />
#      <output id="result-3f279244-e92d-4613-b275-a10c435b2bf8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving zebra.png to zebra.png

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
img1 = cv2.imread('zebra.png')
img=cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
img[55,55] = [255,255,255]
px = img[55,55]
img[100:150, 100:150] = [255,0,0]
butterfly = img[37:111, 107:194]
img[0:74, 0:87] = butterfly


fig = plt.figure(figsize = (14,14), dpi = 100)
ax = plt.subplot("121")
ax.imshow(img)
ax.set_title("GT")
plt.grid(0)
plt.show()

# %%
print(img.shape)
# Out:
# (390, 586, 3)

# %%
#CORNR DETECTION
#corner detection is used for motion tracking , character recognition
#LECTURE NO 13


import numpy as np
import cv2

img = cv2.imread('butterfly_GT.bmp')
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
gray = np.float32(gray)

corners = cv2.goodFeaturesToTrack(gray, 100, 0.01, 10)
corners = np.int0(corners)
for corner in corners:
    x,y = corner.ravel()
    cv2.circle(img,(x,y),3,255,-1)
    
cv2.imshow('Corner',img)
