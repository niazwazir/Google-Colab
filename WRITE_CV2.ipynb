# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread('baby_GT.png', cv2.IMREAD_UNCHANGED)
cv2.imwrite('ABC.png',img)
img1 = cv2.imread('ABC.png', cv2.IMREAD_UNCHANGED)

# %%
img_cvt=cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
plt.imshow(img_cvt)
plt.axis('off')
plt.show()

# %%
cv2.imshow('2X_LRIMAGE',img1)
cv2.waitKey(0) #image will not show until this is called
cv2.destroyAllWindows() #make sure window closes cleanly
