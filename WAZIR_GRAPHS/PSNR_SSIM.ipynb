# %%
import numpy as np
import matplotlib.pyplot as plt

# Sample data: replace these with your actual images or methods' outputs
methods = ['Bicubic', 'SRCNN', 'VDSR', 'DRCN', 'LapSRN', 'EDSR', 'MRISD (Our)']
psnr_values = [34.53, 36.46, 37.47, 37.48, 37.54, 37.64, 37.73]  # PSNR values for each method
ssim_values = [0.9011, 0.9678, 0.9782, 0.9781, 0.9785, 0.9789, 0.9792]  # SSIM values for each method

bubble_sizes = [100, 150, 200, 250, 300, 350, 400]  # Bubble sizes for each method


# Define colors for each method
colors = ['red', 'green', 'blue', 'orange', 'purple', 'cyan', 'magenta']

# Create a figure and axis
fig, ax1 = plt.subplots(figsize=(12, 6))

# Plot PSNR values as bubbles on the left y-axis
for i in range(len(methods)):
    ax1.scatter(methods[i], psnr_values[i], s=bubble_sizes[i], alpha=0.5,
                color=colors[i], edgecolors='w', linewidth=2)

ax1.set_xlabel('Methods', fontsize=14)
ax1.set_ylabel('PSNR (dB)', color='black', fontsize=14)
ax1.tick_params(axis='y', labelcolor='black')

# Create a second y-axis for SSIM values
ax2 = ax1.twinx()
for i in range(len(methods)):
    ax2.scatter(methods[i], ssim_values[i], s=bubble_sizes[i], alpha=0.5,
                color=colors[i], edgecolors='w', linewidth=2)

ax2.set_ylabel('SSIM', color='black', fontsize=14)
ax2.tick_params(axis='y', labelcolor='black')

# Title and layout adjustments
#plt.title('Bubble Graph of PSNR and SSIM Across Methods', fontsize=16)

# Create legends for both axes
handles = [plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=color,
                       markersize=np.sqrt(size), label=method) for color, size, method in zip(colors, bubble_sizes, methods)]
ax1.legend(handles=handles, title="Methods", loc='upper left')

# Show grid for better readability
ax1.grid(True)

# Show plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Data for the methods and metrics
methods = ['Bicubic', 'SRCNN', 'VDSR', 'DRCN', 'LapSRN', 'EDSR', 'MRISD (Our)']
psnr_values = {
    '2x': [34.53, 36.46, 37.47, 37.48, 37.54, 37.64, 37.73],
    '3x': [33.21, 34.94, 35.23, 35.24, 35.28, 35.34, 35.40],
    '4x': [31.38, 33.39, 34.35, 34.33, 34.41, 34.41, 34.44]
}
ssim_values = {
    '2x': [0.9011, 0.9678, 0.9782, 0.9781, 0.9785, 0.9789, 0.9792],
    '3x': [0.9154, 0.9360, 0.9439, 0.9440, 0.9450, 0.9458, 0.9467],
    '4x': [0.9003, 0.9078, 0.9088, 0.9084, 0.9109, 0.9112, 0.9121]
}

# Bubble sizes for visualization
bubble_sizes = [100 * (i + 1) for i in range(len(methods))]
colors = ['red', 'green', 'blue']
scales = ['2x', '3x', '4x']

# Create figure and axis
fig, ax1 = plt.subplots(figsize=(14, 7))

# Plot PSNR and SSIM values as bubbles
for i, method in enumerate(methods):
    for j, scale in enumerate(scales):
        ax1.scatter(method, psnr_values[scale][i], s=bubble_sizes[i], alpha=0.5,
                    color=colors[j], edgecolors='w', linewidth=1.5, label=f'PSNR {scale}' if i == 0 else "")
        ax1.scatter(method, ssim_values[scale][i], s=bubble_sizes[i], alpha=0.5,
                    color=colors[j], edgecolors='w', linewidth=1.5, label=f'SSIM {scale}' if i == 0 else "")

# Set labels and titles
ax1.set_xlabel('Methods', fontsize=14)
ax1.set_ylabel('Metric Values (PSNR & SSIM)', fontsize=14)
#plt.title('Bubble Chart of PSNR and SSIM Across Methods at Different Scaling Factors', fontsize=16)

# Create custom legend handles for PSNR and SSIM
handles_psnr = [plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=color, markersize=10)
                for color in colors]
handles_ssim = [plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=color, markersize=10)
                for color in colors]

# Add custom legends separately
legend_psnr = ax1.legend(handles_psnr, [f'PSNR {scale}' for scale in scales], title="PSNR Scaling Factors", loc='lower left')
ax1.add_artist(legend_psnr)  # Ensures the first legend stays on the plot
ax1.legend(handles_ssim, [f'SSIM {scale}' for scale in scales], title="SSIM Scaling Factors", loc='lower right')

# Add grid for clarity
ax1.grid(True, which='both', linestyle='--', linewidth=0.5)

# Display the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Data for the methods and metrics
methods = ['Bicubic', 'SRCNN', 'VDSR', 'DRCN', 'LapSRN', 'EDSR', 'MRISD (Our)']
psnr_values = {
    '2x': [34.53, 36.46, 37.47, 37.48, 37.54, 37.64, 37.73],
    '3x': [33.21, 34.94, 35.23, 35.24, 35.28, 35.34, 35.40],
    '4x': [31.38, 33.39, 34.35, 34.33, 34.41, 34.41, 34.44]
}
ssim_values = {
    '2x': [0.9011, 0.9678, 0.9782, 0.9781, 0.9785, 0.9789, 0.9792],
    '3x': [0.9154, 0.9360, 0.9439, 0.9440, 0.9450, 0.9458, 0.9467],
    '4x': [0.9003, 0.9078, 0.9088, 0.9084, 0.9109, 0.9112, 0.9121]
}

# Bubble sizes for visualization
bubble_sizes = [100 * (i + 1) for i in range(len(methods))]
colors = ['red', 'green', 'blue']
scales = ['2x', '3x', '4x']

# Create figure and primary y-axis (for PSNR)
fig, ax1 = plt.subplots(figsize=(14, 7))

# Create a secondary y-axis (for SSIM)
ax2 = ax1.twinx()

# Plot PSNR values on the left y-axis
for i, method in enumerate(methods):
    for j, scale in enumerate(scales):
        ax1.scatter(method, psnr_values[scale][i], s=bubble_sizes[i], alpha=0.5,
                    color=colors[j], edgecolors='w', linewidth=1.5, label=f'PSNR {scale}' if i == 0 else "")

# Plot SSIM values on the right y-axis
for i, method in enumerate(methods):
    for j, scale in enumerate(scales):
        ax2.scatter(method, ssim_values[scale][i], s=bubble_sizes[i], alpha=0.5,
                    color=colors[j], edgecolors='w', linewidth=1.5, label=f'SSIM {scale}' if i == 0 else "")

# Set labels and titles
ax1.set_xlabel('Methods', fontsize=14)
ax1.set_ylabel('PSNR (dB)', fontsize=14, color='black')
ax2.set_ylabel('SSIM', fontsize=14, color='black')

# Set grid for clarity
ax1.grid(True, which='both', linestyle='--', linewidth=0.5)

# Create custom legend handles for PSNR and SSIM
handles_psnr = [plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=color, markersize=10)
                for color in colors]
handles_ssim = [plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=color, markersize=10)
                for color in colors]

# Add custom legends
legend_psnr = ax1.legend(handles_psnr, [f'PSNR {scale}' for scale in scales], title="PSNR Scaling Factors", loc='upper left')
ax1.add_artist(legend_psnr)  # Ensures the first legend stays on the plot
ax2.legend(handles_ssim, [f'SSIM {scale}' for scale in scales], title="SSIM Scaling Factors", loc='upper right')

# Display the plot
#plt.title('Bubble Chart of PSNR and SSIM Across Methods at Different Scaling Factors', fontsize=16)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Data for the methods and metrics
methods = ['Bicubic', 'SRCNN', 'VDSR', 'DRCN', 'LapSRN', 'EDSR', 'MRISD (Our)']
psnr_values = {
    '2x': [34.53, 36.46, 37.47, 37.48, 37.54, 37.64, 37.73],
    '3x': [33.21, 34.94, 35.23, 35.24, 35.28, 35.34, 35.40],
    '4x': [31.38, 33.39, 34.35, 34.33, 34.41, 34.41, 34.44]
}
ssim_values = {
    '2x': [0.9011, 0.9678, 0.9782, 0.9781, 0.9785, 0.9789, 0.9792],
    '3x': [0.9154, 0.9360, 0.9439, 0.9440, 0.9450, 0.9458, 0.9467],
    '4x': [0.9003, 0.9078, 0.9088, 0.9084, 0.9109, 0.9112, 0.9121]
}

# Bubble sizes for visualization
bubble_sizes = [100 * (i + 1) for i in range(len(methods))]

# Define colors for PSNR and SSIM bubbles
psnr_colors = ['red', 'green', 'blue']
ssim_colors = ['orange', 'purple', 'cyan']
scales = ['2x', '3x', '4x']

# Create figure and primary y-axis (for PSNR)
fig, ax1 = plt.subplots(figsize=(14, 7))

# Create a secondary y-axis (for SSIM)
ax2 = ax1.twinx()

# Plot PSNR values on the left y-axis with distinct colors
for i, method in enumerate(methods):
    for j, scale in enumerate(scales):
        ax1.scatter(method, psnr_values[scale][i], s=bubble_sizes[i], alpha=0.5,
                    color=psnr_colors[j], edgecolors='w', linewidth=1.5, label=f'PSNR {scale}' if i == 0 else "")

# Plot SSIM values on the right y-axis with different colors
for i, method in enumerate(methods):
    for j, scale in enumerate(scales):
        ax2.scatter(method, ssim_values[scale][i], s=bubble_sizes[i], alpha=0.5,
                    color=ssim_colors[j], edgecolors='w', linewidth=1.5, label=f'SSIM {scale}' if i == 0 else "")

# Set labels and titles
ax1.set_xlabel('Methods', fontsize=14)
ax1.set_ylabel('PSNR (dB)', fontsize=14, color='black')
ax2.set_ylabel('SSIM', fontsize=14, color='black')

# Set grid for clarity
ax1.grid(True, which='both', linestyle='--', linewidth=0.5)

# Create custom legend handles for PSNR and SSIM
handles_psnr = [plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=color, markersize=10)
                for color in psnr_colors]
handles_ssim = [plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=color, markersize=10)
                for color in ssim_colors]

# Add custom legends
legend_psnr = ax1.legend(handles_psnr, [f'PSNR {scale}' for scale in scales], title="PSNR Scaling Factors", loc='upper left')
ax1.add_artist(legend_psnr)  # Ensures the first legend stays on the plot
ax2.legend(handles_ssim, [f'SSIM {scale}' for scale in scales], title="SSIM Scaling Factors", loc='upper right')

# Display the plot
#plt.title('Bubble Chart of PSNR and SSIM Across Methods at Different Scaling Factors', fontsize=16)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Data for the methods and metrics
methods = ['Bicubic', 'SRCNN', 'VDSR', 'DRCN', 'LapSRN', 'EDSR', 'MRISD (Our)']
psnr_values = {
    '2x': [34.53, 36.46, 37.47, 37.48, 37.54, 37.64, 37.73],
    '3x': [33.21, 34.94, 35.23, 35.24, 35.28, 35.34, 35.40],
    '4x': [31.38, 33.39, 34.35, 34.33, 34.41, 34.41, 34.44]
}
ssim_values = {
    '2x': [0.9011, 0.9678, 0.9782, 0.9781, 0.9785, 0.9789, 0.9792],
    '3x': [0.9154, 0.9360, 0.9439, 0.9440, 0.9450, 0.9458, 0.9467],
    '4x': [0.9003, 0.9078, 0.9088, 0.9084, 0.9109, 0.9112, 0.9121]
}

# Bubble sizes for visualization
bubble_sizes = [100 * (i + 1) for i in range(len(methods))]

# Define colors for PSNR and SSIM bubbles
psnr_colors = ['red', 'green', 'blue']
ssim_colors = ['orange', 'purple', 'cyan']
scales = ['2x', '3x', '4x']

# Create figure and primary y-axis (for PSNR)
fig, ax1 = plt.subplots(figsize=(14, 7))

# Create a secondary y-axis (for SSIM)
ax2 = ax1.twinx()

# Plot PSNR values on the left y-axis with distinct colors
for i, method in enumerate(methods):
    for j, scale in enumerate(scales):
        ax1.scatter(method, psnr_values[scale][i], s=bubble_sizes[i], alpha=0.5,
                    color=psnr_colors[j], edgecolors='w', linewidth=1.5, label=f'PSNR {scale}' if i == 0 else "")

# Plot SSIM values on the right y-axis with different colors
for i, method in enumerate(methods):
    for j, scale in enumerate(scales):
        ax2.scatter(method, ssim_values[scale][i], s=bubble_sizes[i], alpha=0.5,
                    color=ssim_colors[j], edgecolors='w', linewidth=1.5, label=f'SSIM {scale}' if i == 0 else "")

# Set labels and titles
ax1.set_xlabel('Methods', fontsize=14)
ax1.set_ylabel('PSNR (dB)', fontsize=14, color='black')
ax2.set_ylabel('SSIM', fontsize=14, color='black')

# Set grid for clarity
ax1.grid(True, which='both', linestyle='--', linewidth=0.5)

# Create custom legend handles for PSNR and SSIM
handles_psnr = [plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=color, markersize=10)
                for color in psnr_colors]
handles_ssim = [plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=color, markersize=10)
                for color in ssim_colors]

# Add custom legends
legend_psnr = ax1.legend(handles_psnr, [f'PSNR {scale}' for scale in scales], title="PSNR Scaling Factors", loc='upper left')
ax1.add_artist(legend_psnr)  # Ensures the first legend stays on the plot
ax2.legend(handles_ssim, [f'SSIM {scale}' for scale in scales], title="SSIM Scaling Factors", loc='upper right')

# Save the plot as a PNG file
plt.title('Bubble Chart of PSNR and SSIM Across Methods at Different Scaling Factors', fontsize=16)
plt.savefig('psnr_ssim_bubble_chart.png', dpi=300, bbox_inches='tight')  # Save with high resolution

# Display the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Data for the methods and metrics
methods = ['Bicubic', 'SRCNN', 'VDSR', 'DRCN', 'LapSRN', 'EDSR', 'MRISD (Our)']
psnr_values = {
    '2x': [34.53, 36.46, 37.47, 37.48, 37.54, 37.64, 37.73],
    '3x': [33.21, 34.94, 35.23, 35.24, 35.28, 35.34, 35.40],
    '4x': [31.38, 33.39, 34.35, 34.33, 34.41, 34.41, 34.44]
}
ssim_values = {
    '2x': [0.9011, 0.9678, 0.9782, 0.9781, 0.9785, 0.9789, 0.9792],
    '3x': [0.9154, 0.9360, 0.9439, 0.9440, 0.9450, 0.9458, 0.9467],
    '4x': [0.9003, 0.9078, 0.9088, 0.9084, 0.9109, 0.9112, 0.9121]
}
param_values = {
    '2x': [0, 57, 665, 1775, 812, 43000, 704],
    '3x': [0, 57, 665, 1775, 812, 43000, 704],
    '4x': [0, 57, 665, 1775, 812, 43000, 704]
}

# Bubble sizes for visualization (scaled based on param_values)
bubble_sizes = [param_values[scale][i] / 100 for scale in scales for i in range(len(methods))]

# Define colors for PSNR and SSIM bubbles
psnr_colors = ['red', 'green', 'blue']
ssim_colors = ['orange', 'purple', 'cyan']
scales = ['2x', '3x', '4x']

# Create figure and primary y-axis (for PSNR)
fig, ax1 = plt.subplots(figsize=(14, 7))

# Create a secondary y-axis (for SSIM)
ax2 = ax1.twinx()

# Plot PSNR values on the left y-axis with distinct colors
for i, method in enumerate(methods):
    for j, scale in enumerate(scales):
        ax1.scatter(method, psnr_values[scale][i], s=bubble_sizes[i], alpha=0.5,
                    color=psnr_colors[j], edgecolors='w', linewidth=1.5, label=f'PSNR {scale}' if i == 0 else "")

# Plot SSIM values on the right y-axis with different colors
for i, method in enumerate(methods):
    for j, scale in enumerate(scales):
        ax2.scatter(method, ssim_values[scale][i], s=bubble_sizes[i], alpha=0.5,
                    color=ssim_colors[j], edgecolors='w', linewidth=1.5, label=f'SSIM {scale}' if i == 0 else "")

# Annotate the chart with `param_values` for each method and scale
for i, method in enumerate(methods):
    for j, scale in enumerate(scales):
        ax1.annotate(f'{param_values[scale][i]}', 
                     (method, psnr_values[scale][i]), 
                     textcoords="offset points", 
                     xytext=(0, 10), ha='center', fontsize=9, color=psnr_colors[j])

# Set labels and titles
ax1.set_xlabel('Methods', fontsize=14)
ax1.set_ylabel('PSNR (dB)', fontsize=14, color='black')
ax2.set_ylabel('SSIM', fontsize=14, color='black')

# Set grid for clarity
ax1.grid(True, which='both', linestyle='--', linewidth=0.5)

# Create custom legend handles for PSNR and SSIM
handles_psnr = [plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=color, markersize=10)
                for color in psnr_colors]
handles_ssim = [plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=color, markersize=10)
                for color in ssim_colors]

# Add custom legends
legend_psnr = ax1.legend(handles_psnr, [f'PSNR {scale}' for scale in scales], title="PSNR Scaling Factors", loc='upper left')
ax1.add_artist(legend_psnr)  # Ensures the first legend stays on the plot
ax2.legend(handles_ssim, [f'SSIM {scale}' for scale in scales], title="SSIM Scaling Factors", loc='upper right')

# Save the plot as a PNG file
#plt.title('Bubble Chart of PSNR and SSIM Across Methods at Different Scaling Factors', fontsize=16)
plt.savefig('psnr_ssim_bubble_chart_with_params.png', dpi=300, bbox_inches='tight')  # Save with high resolution

# Display the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Data for the methods and metrics
methods = ['Bicubic', 'SRCNN', 'VDSR', 'DRCN', 'LapSRN', 'EDSR', 'MRISD (Our)']
psnr_values = {
    '2x': [34.53, 36.46, 37.47, 37.48, 37.54, 37.64, 37.73],
    '3x': [33.21, 34.94, 35.23, 35.24, 35.28, 35.34, 35.40],
    '4x': [31.38, 33.39, 34.35, 34.33, 34.41, 34.41, 34.44]
}
ssim_values = {
    '2x': [0.9011, 0.9678, 0.9782, 0.9781, 0.9785, 0.9789, 0.9792],
    '3x': [0.9154, 0.9360, 0.9439, 0.9440, 0.9450, 0.9458, 0.9467],
    '4x': [0.9003, 0.9078, 0.9088, 0.9084, 0.9109, 0.9112, 0.9121]
}
param_values = {
    '2x': [0, 57, 665, 1775, 812, 43000, 704],
    '3x': [0, 57, 665, 1775, 812, 43000, 704],
    '4x': [0, 57, 665, 1775, 812, 43000, 704]
}

# Bubble sizes for visualization (scaled based on param_values)
bubble_sizes = [param_values[scale][i] / 100 for scale in scales for i in range(len(methods))]

# Define colors for PSNR and SSIM bubbles
psnr_colors = ['red', 'green', 'blue']
ssim_colors = ['orange', 'purple', 'cyan']
scales = ['2x', '3x', '4x']

# Create figure and primary y-axis (for PSNR)
fig, ax1 = plt.subplots(figsize=(14, 7))

# Create a secondary y-axis (for SSIM)
ax2 = ax1.twinx()

# Plot PSNR values on the left y-axis with distinct colors
for i, method in enumerate(methods):
    for j, scale in enumerate(scales):
        ax1.scatter(method, psnr_values[scale][i], s=bubble_sizes[i], alpha=0.5,
                    color=psnr_colors[j], edgecolors='w', linewidth=1.5, label=f'PSNR {scale}' if i == 0 else "")

# Plot SSIM values on the right y-axis with different colors
for i, method in enumerate(methods):
    for j, scale in enumerate(scales):
        ax2.scatter(method, ssim_values[scale][i], s=bubble_sizes[i], alpha=0.5,
                    color=ssim_colors[j], edgecolors='w', linewidth=1.5, label=f'SSIM {scale}' if i == 0 else "")

# Annotate the chart with `param_values` for each method and scale
for i, method in enumerate(methods):
    for j, scale in enumerate(scales):
        ax1.annotate(f'{param_values[scale][i]}', 
                     (method, psnr_values[scale][i]), 
                     textcoords="offset points", 
                     xytext=(0, 10), ha='center', fontsize=9, color=psnr_colors[j])

# Set labels and titles
ax1.set_xlabel('Methods', fontsize=14)
ax1.set_ylabel('PSNR (dB)', fontsize=14, color='black')
ax2.set_ylabel('SSIM', fontsize=14, color='black')

# Set grid for clarity
ax1.grid(True, which='both', linestyle='--', linewidth=0.5)

# Create custom legend handles for PSNR and SSIM
handles_psnr = [plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=color, markersize=10)
                for color in psnr_colors]
handles_ssim = [plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=color, markersize=10)
                for color in ssim_colors]

# Create custom legend for `param_values` based on bubble sizes
handles_param = [plt.Line2D([0], [0], marker='o', color='w', markerfacecolor='gray', markersize=size, label=f'Param {scale}')
                 for size, scale in zip(bubble_sizes, scales)]

# Add custom legends
legend_psnr = ax1.legend(handles_psnr, [f'PSNR {scale}' for scale in scales], title="PSNR Scaling Factors", loc='upper left')
ax1.add_artist(legend_psnr)  # Ensures the first legend stays on the plot
ax2.legend(handles_ssim, [f'SSIM {scale}' for scale in scales], title="SSIM Scaling Factors", loc='upper right')

# Add param_values legend
ax1.legend(handles_param, [f'Param {scale}' for scale in scales], title="Parameter Values", loc='lower left')

# Save the plot as a PNG file
plt.title('Bubble Chart of PSNR and SSIM Across Methods at Different Scaling Factors', fontsize=16)
plt.savefig('psnr_ssim_bubble_chart_with_params_and_legend.png', dpi=300, bbox_inches='tight')  # Save with high resolution

# Display the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Data for the methods and metrics
methods = ['Bicubic', 'SRCNN', 'VDSR', 'DRCN', 'LapSRN', 'EDSR', 'MRISD (Our)']
psnr_values = {
    '2x': [34.53, 36.46, 37.47, 37.48, 37.54, 37.64, 37.73],
    '3x': [33.21, 34.94, 35.23, 35.24, 35.28, 35.34, 35.40],
    '4x': [31.38, 33.39, 34.35, 34.33, 34.41, 34.41, 34.44]
}
ssim_values = {
    '2x': [0.9011, 0.9678, 0.9782, 0.9781, 0.9785, 0.9789, 0.9792],
    '3x': [0.9154, 0.9360, 0.9439, 0.9440, 0.9450, 0.9458, 0.9467],
    '4x': [0.9003, 0.9078, 0.9088, 0.9084, 0.9109, 0.9112, 0.9121]
}
param_values = {
    '2x': [0, 57, 665, 1775, 812, 43000, 704],
    '3x': [0, 57, 665, 1775, 812, 43000, 704],
    '4x': [0, 57, 665, 1775, 812, 43000, 704]
}

# Bubble sizes for visualization (scaled based on param_values)
bubble_sizes = [param_values[scale][i] / 100 for scale in ['2x', '3x', '4x'] for i in range(len(methods))]

# Define colors for PSNR and SSIM bubbles
psnr_colors = ['red', 'green', 'blue']
ssim_colors = ['orange', 'purple', 'cyan']
param_colors = ['red', 'green', 'blue']  # Matching scaling factor colors for param_values
scales = ['2x', '3x', '4x']

# Create figure and primary y-axis (for PSNR)
fig, ax1 = plt.subplots(figsize=(14, 7))

# Create a secondary y-axis (for SSIM)
ax2 = ax1.twinx()

# Plot PSNR values on the left y-axis with distinct colors
for i, method in enumerate(methods):
    for j, scale in enumerate(scales):
        ax1.scatter(method, psnr_values[scale][i], s=bubble_sizes[i], alpha=0.5,
                    color=psnr_colors[j], edgecolors='w', linewidth=1.5, label=f'PSNR {scale}' if i == 0 else "")

# Plot SSIM values on the right y-axis with different colors
for i, method in enumerate(methods):
    for j, scale in enumerate(scales):
        ax2.scatter(method, ssim_values[scale][i], s=bubble_sizes[i], alpha=0.5,
                    color=ssim_colors[j], edgecolors='w', linewidth=1.5, label=f'SSIM {scale}' if i == 0 else "")

# Annotate the chart with `param_values` for each method and scale
for i, method in enumerate(methods):
    for j, scale in enumerate(scales):
        ax1.annotate(f'{param_values[scale][i]}', 
                     (method, psnr_values[scale][i]), 
                     textcoords="offset points", 
                     xytext=(0, 10), ha='center', fontsize=9, color=psnr_colors[j])

# Set labels and titles
ax1.set_xlabel('Methods', fontsize=14)
ax1.set_ylabel('PSNR (dB)', fontsize=14, color='black')
ax2.set_ylabel('SSIM', fontsize=14, color='black')

# Set grid for clarity
ax1.grid(True, which='both', linestyle='--', linewidth=0.5)

# Create custom legend handles for PSNR and SSIM
handles_psnr = [plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=color, markersize=10)
                for color in psnr_colors]
handles_ssim = [plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=color, markersize=10)
                for color in ssim_colors]

# Create custom legend for `param_values` based on bubble sizes and colors
handles_param = [plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=color, markersize=10, label=f'Param {scale}')
                 for color, scale in zip(param_colors, scales)]

# Add custom legends
legend_psnr = ax1.legend(handles_psnr, [f'PSNR {scale}' for scale in scales], title="PSNR Scaling Factors", loc='upper left')
ax1.add_artist(legend_psnr)  # Ensures the first legend stays on the plot
ax2.legend(handles_ssim, [f'SSIM {scale}' for scale in scales], title="SSIM Scaling Factors", loc='upper right')

# Add param_values legend with color
ax1.legend(handles_param, [f'Param {scale}' for scale in scales], title="Parameter Values", loc='lower left')

# Save the plot as a PNG file
plt.title('Bubble Chart of PSNR and SSIM Across Methods at Different Scaling Factors', fontsize=16)
plt.savefig('psnr_ssim_bubble_chart_with_params_and_colored_legend.png', dpi=300, bbox_inches='tight')  # Save with high resolution

# Display the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Data for the methods and metrics
methods = ['Bicubic', 'SRCNN', 'VDSR', 'DRCN', 'LapSRN', 'EDSR', 'MRISD (Our)']
psnr_values = {
    '2x': [34.53, 36.46, 37.47, 37.48, 37.54, 37.64, 37.73],
    '3x': [33.21, 34.94, 35.23, 35.24, 35.28, 35.34, 35.40],
    '4x': [31.38, 33.39, 34.35, 34.33, 34.41, 34.41, 34.44]
}
ssim_values = {
    '2x': [0.9011, 0.9678, 0.9782, 0.9781, 0.9785, 0.9789, 0.9792],
    '3x': [0.9154, 0.9360, 0.9439, 0.9440, 0.9450, 0.9458, 0.9467],
    '4x': [0.9003, 0.9078, 0.9088, 0.9084, 0.9109, 0.9112, 0.9121]
}
param_values = {
    '2x': [0, 57, 665, 1775, 812, 43000, 704],
    '3x': [0, 57, 665, 1775, 812, 43000, 704],
    '4x': [0, 57, 665, 1775, 812, 43000, 704]
}

# Bubble sizes for visualization (scaled based on param_values)
bubble_sizes = [param_values[scale][i] / 100 for scale in ['2x', '3x', '4x'] for i in range(len(methods))]

# Define colors for PSNR and SSIM bubbles
psnr_colors = ['red', 'green', 'blue']
ssim_colors = ['orange', 'purple', 'cyan']
param_colors = ['yellow', 'pink', 'brown']  # Different colors for param_values
scales = ['2x', '3x', '4x']

# Create figure and primary y-axis (for PSNR)
fig, ax1 = plt.subplots(figsize=(14, 7))

# Create a secondary y-axis (for SSIM)
ax2 = ax1.twinx()

# Plot PSNR values on the left y-axis with distinct colors
for i, method in enumerate(methods):
    for j, scale in enumerate(scales):
        ax1.scatter(method, psnr_values[scale][i], s=bubble_sizes[i], alpha=0.5,
                    color=psnr_colors[j], edgecolors='w', linewidth=1.5, label=f'PSNR {scale}' if i == 0 else "")

# Plot SSIM values on the right y-axis with different colors
for i, method in enumerate(methods):
    for j, scale in enumerate(scales):
        ax2.scatter(method, ssim_values[scale][i], s=bubble_sizes[i], alpha=0.5,
                    color=ssim_colors[j], edgecolors='w', linewidth=1.5, label=f'SSIM {scale}' if i == 0 else "")

# Annotate the chart with `param_values` for each method and scale
for i, method in enumerate(methods):
    for j, scale in enumerate(scales):
        ax1.annotate(f'{param_values[scale][i]}', 
                     (method, psnr_values[scale][i]), 
                     textcoords="offset points", 
                     xytext=(0, 10), ha='center', fontsize=9, color=param_colors[j])

# Set labels and titles
ax1.set_xlabel('Methods', fontsize=14)
ax1.set_ylabel('PSNR (dB)', fontsize=14, color='black')
ax2.set_ylabel('SSIM', fontsize=14, color='black')

# Set grid for clarity
ax1.grid(True, which='both', linestyle='--', linewidth=0.5)

# Create custom legend handles for PSNR and SSIM
handles_psnr = [plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=color, markersize=10)
                for color in psnr_colors]
handles_ssim = [plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=color, markersize=10)
                for color in ssim_colors]

# Create custom legend for `param_values` based on new colors
handles_param = [plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=color, markersize=10, label=f'Param {scale}')
                 for color, scale in zip(param_colors, scales)]

# Add custom legends
legend_psnr = ax1.legend(handles_psnr, [f'PSNR {scale}' for scale in scales], title="PSNR Scaling Factors", loc='upper left')
ax1.add_artist(legend_psnr)  # Ensures the first legend stays on the plot
ax2.legend(handles_ssim, [f'SSIM {scale}' for scale in scales], title="SSIM Scaling Factors", loc='upper right')

# Add param_values legend with color
ax1.legend(handles_param, [f'Param {scale}' for scale in scales], title="Parameter Values", loc='lower left')

# Save the plot as a PNG file
plt.title('Bubble Chart of PSNR, SSIM, and Parameter Values Across Methods at Different Scaling Factors', fontsize=16)
plt.savefig('psnr_ssim_param_bubble_chart_colored_legend.png', dpi=300, bbox_inches='tight')  # Save with high resolution

# Display the plot
plt.show()
