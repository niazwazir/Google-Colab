# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e6866844-d49b-4f36-a4b1-b9ac46144ccd" name="files[]" multiple disabled />
#      <output id="result-e6866844-d49b-4f36-a4b1-b9ac46144ccd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving zebra.bmp to zebra.bmp

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img1 = cv2.imread("zebra.bmp")
img_cvt=cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
plt.imshow(img_cvt)
plt.grid(None)
plt.show()

# %%
print(img1.shape)
# Out:
# (391, 586, 3)

# %%
IMG_SIZE = 500
smallimg1 = cv2.resize(img1,(IMG_SIZE,IMG_SIZE))
plt.imshow(smallimg1,cmap="gray")
plt.grid(None)

# %%
print(smallimg1.shape)
# Out:
# (500, 500, 3)

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e3704199-30bd-4331-9762-8e525bc881de" name="files[]" multiple disabled />
#      <output id="result-e3704199-30bd-4331-9762-8e525bc881de">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving butterfly_GT.bmp to butterfly_GT.bmp

# %%
img2 = cv2.imread("butterfly_GT.bmp")
img_cvt=cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)
plt.imshow(img_cvt)
plt.grid(None)
plt.show()

# %%
print(img2.shape)
# Out:
# (256, 256, 3)

# %%
IMG_SIZE = 500
smallimg2 = cv2.resize(img_cvt,(IMG_SIZE,IMG_SIZE))
plt.imshow(smallimg2,cmap="gray")
plt.grid(None)

# %%
print(smallimg2.shape)
# Out:
# (500, 500, 3)

# %%
add = smallimg1 + smallimg2 
plt.imshow(add,cmap="gray")
plt.grid(None)
