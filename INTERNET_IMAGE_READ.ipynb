# %%
import numpy as np
import matplotlib.image as mpimg
from matplotlib import pyplot as plt

# %%
img = mpimg.imread('http://vllab.ucmerced.edu/wlai24/LapSRN/results/Set5/x2/baby_x2_MSLapSRN.png')
plt.imshow(img)
plt.axis("off")
plt.grid(None)
plt.show()

# %%
img1 = mpimg.imread('http://vllab.ucmerced.edu/wlai24/LapSRN/results/Set5/x2/butterfly_x2_SCN.png')
plt.imshow(img1)
plt.axis("off")
plt.grid(None)
plt.show()
