# %%
###############THIS CODE SUCCESSFULLY RUN ON MY LOCAL MACHINE
#!pip install super-image
############ CARN-SCALE-2X ############# SET5

# %%
# !git clone https://github.com/niazwazir/HUGGING_FACE_IMAGE_SR_WAZIR.git

# %%
ls

# %%
cd HUGGING_FACE_IMAGE_SR_WAZIR

# %%
ls

# %%
######################## CARN METHOD####################
# !mkdir WAZIR_CARN_X2
# !mkdir WAZIR_CARN_X3
# !mkdir WAZIR_CARN_X4

# %%
import os
from super_image import CarnModel, ImageLoader
from PIL import Image

def process_images(input_folder, output_folder, model_name='eugenesiow/carn', scale=2):
    # Load the pre-trained model
    model = CarnModel.from_pretrained(model_name, scale=scale)

    # Ensure the output folder exists
    os.makedirs(output_folder, exist_ok=True)

    # Iterate through all images in the input folder
    for filename in os.listdir(input_folder):
        if filename.endswith(('.png', '.jpg', '.jpeg')):  # Check for image file extensions
            # Load the image
            image_path = os.path.join(input_folder, filename)
            print(f'Processing {image_path}...')
            image = Image.open(image_path)

            # Prepare the image for the model
            inputs = ImageLoader.load_image(image)

            # Perform super-resolution
            preds = model(inputs)

            # Save the output image
            output_path = os.path.join(output_folder, f'scaled_{filename}')
            ImageLoader.save_image(preds, output_path)
            print(f'Saved scaled image to {output_path}')

# Example usage
input_folder = 'LR_X2'  # Replace with your input folder path
output_folder = 'WAZIR_CARN_X2'  # Replace with your output folder path
process_images(input_folder, output_folder)


import os
import cv2
import numpy as np

def calculate_psnr(reference, distorted):
    """Calculate PSNR between two images."""
    mse = np.mean((reference - distorted) ** 2)
    if mse == 0:
        return float('inf')  # If MSE is zero, PSNR is infinite
    max_pixel_value = 255.0  # For 8-bit images
    psnr = 20 * np.log10(max_pixel_value / np.sqrt(mse))
    return psnr

def calculate_metrics(hr_folder, sr_folder):
    psnr_values = []

    # Get lists of image files in both folders
    hr_images = [f for f in os.listdir(hr_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]
    sr_images = [f for f in os.listdir(sr_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]

    # Ensure both folders have the same number of images
    if len(hr_images) != len(sr_images):
        raise ValueError("The number of images in HR and SR folders must be the same.")

    # Loop through each image pair
    for i in range(len(hr_images)):
        hr_image_path = os.path.join(hr_folder, hr_images[i])
        sr_image_path = os.path.join(sr_folder, sr_images[i])

        # Read HR and SR images
        hr_image = cv2.imread(hr_image_path)
        sr_image = cv2.imread(sr_image_path)

        # Calculate PSNR
        psnr_value = calculate_psnr(hr_image, sr_image)
        psnr_values.append(psnr_value)

        # Display the PSNR value for the current image pair
        print(f'Image: {hr_images[i]} | PSNR: {psnr_value:.4f} dB')

    # Calculate average PSNR
    average_psnr = np.mean(psnr_values)
    print(f'Average PSNR: {average_psnr:.4f} dB')

# Example usage
hr_folder = 'ORIGINAL_X2'  # Replace with your HR folder path
sr_folder = 'WAZIR_CARN_X2'   # Replace with your SR folder path
calculate_metrics(hr_folder, sr_folder)


#############################################SSIM##########################
import os
import cv2
import numpy as np
from skimage.metrics import structural_similarity as ssim

def calculate_ssim(reference, distorted):
    """Calculate SSIM between two images."""
    if reference.shape != distorted.shape:
        raise ValueError("Reference and distorted images must have the same dimensions.")
    
    # Convert images to grayscale if they are not already
    if len(reference.shape) == 3:
        reference = cv2.cvtColor(reference, cv2.COLOR_BGR2GRAY)
    if len(distorted.shape) == 3:
        distorted = cv2.cvtColor(distorted, cv2.COLOR_BGR2GRAY)

    return ssim(reference, distorted)

def calculate_metrics(hr_folder, sr_folder):
    ssim_values = []

    # Get lists of image files in both folders
    hr_images = [f for f in os.listdir(hr_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]
    sr_images = [f for f in os.listdir(sr_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]

    # Ensure both folders have the same number of images
    if len(hr_images) != len(sr_images):
        raise ValueError("The number of images in HR and SR folders must be the same.")

    # Loop through each image pair
    for i in range(len(hr_images)):
        hr_image_path = os.path.join(hr_folder, hr_images[i])
        sr_image_path = os.path.join(sr_folder, sr_images[i])

        # Read HR and SR images
        hr_image = cv2.imread(hr_image_path)
        sr_image = cv2.imread(sr_image_path)

        # Calculate SSIM
        ssim_value = calculate_ssim(hr_image, sr_image)
        ssim_values.append(ssim_value)

        # Display the SSIM value for the current image pair
        print(f'Image: {hr_images[i]} | SSIM: {ssim_value:.4f}')

    # Calculate average SSIM
    average_ssim = np.mean(ssim_values)
    print(f'Average SSIM: {average_ssim:.4f}')

# Example usage
hr_folder = 'ORIGINAL_X2'  # Replace with your HR folder path
sr_folder = 'WAZIR_CARN_X2'   # Replace with your SR folder path
calculate_metrics(hr_folder, sr_folder)



import os
import cv2
import matplotlib.pyplot as plt

def plot_images(hr_folder, sr_folder):
    # Get lists of image files in both folders
    hr_images = [f for f in os.listdir(hr_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]
    sr_images = [f for f in os.listdir(sr_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]

    # Ensure both folders have the same number of images
    if len(hr_images) != len(sr_images):
        raise ValueError("The number of images in HR and SR folders must be the same.")

    # Set up the plot
    num_images = len(hr_images)
    plt.figure(figsize=(15, 5 * num_images))

    # Loop through each image pair
    for i in range(num_images):
        hr_image_path = os.path.join(hr_folder, hr_images[i])
        sr_image_path = os.path.join(sr_folder, sr_images[i])

        # Read images
        hr_image = cv2.imread(hr_image_path)
        sr_image = cv2.imread(sr_image_path)

        # Convert BGR to RGB (OpenCV loads images in BGR format)
        hr_image = cv2.cvtColor(hr_image, cv2.COLOR_BGR2RGB)
        sr_image = cv2.cvtColor(sr_image, cv2.COLOR_BGR2RGB)

        # Plot HR image
        plt.subplot(num_images, 2, 2 * i + 1)
        plt.imshow(hr_image)
        plt.title(f'High Resolution - {hr_images[i]}')
        plt.axis('off')

        # Plot SR image
        plt.subplot(num_images, 2, 2 * i + 2)
        plt.imshow(sr_image)
        plt.title(f'Super Resolution - {sr_images[i]}')
        plt.axis('off')

    plt.tight_layout()
    plt.show()

# Example usage
hr_folder = 'ORIGINAL_X2'  # Replace with your HR folder path
sr_folder = 'WAZIR_CARN_X2'   # Replace with your SR folder path
plot_images(hr_folder, sr_folder)

# %%
############ CARN-SCALE-3X ############# SET5

# %%
import os
from super_image import CarnModel, ImageLoader
from PIL import Image

def process_images(input_folder, output_folder, model_name='eugenesiow/carn', scale=3):
    # Load the pre-trained model
    model = CarnModel.from_pretrained(model_name, scale=scale)

    # Ensure the output folder exists
    os.makedirs(output_folder, exist_ok=True)

    # Iterate through all images in the input folder
    for filename in os.listdir(input_folder):
        if filename.endswith(('.png', '.jpg', '.jpeg')):  # Check for image file extensions
            # Load the image
            image_path = os.path.join(input_folder, filename)
            print(f'Processing {image_path}...')
            image = Image.open(image_path)

            # Prepare the image for the model
            inputs = ImageLoader.load_image(image)

            # Perform super-resolution
            preds = model(inputs)

            # Save the output image
            output_path = os.path.join(output_folder, f'scaled_{filename}')
            ImageLoader.save_image(preds, output_path)
            print(f'Saved scaled image to {output_path}')

# Example usage
input_folder = 'LR_X3'  # Replace with your input folder path
output_folder = 'WAZIR_CARN_X3'  # Replace with your output folder path
process_images(input_folder, output_folder)



import os
import cv2
import numpy as np

def calculate_psnr(reference, distorted):
    """Calculate PSNR between two images."""
    mse = np.mean((reference - distorted) ** 2)
    if mse == 0:
        return float('inf')  # If MSE is zero, PSNR is infinite
    max_pixel_value = 255.0  # For 8-bit images
    psnr = 20 * np.log10(max_pixel_value / np.sqrt(mse))
    return psnr

def calculate_metrics(hr_folder, sr_folder):
    psnr_values = []

    # Get lists of image files in both folders
    hr_images = [f for f in os.listdir(hr_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]
    sr_images = [f for f in os.listdir(sr_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]

    # Ensure both folders have the same number of images
    if len(hr_images) != len(sr_images):
        raise ValueError("The number of images in HR and SR folders must be the same.")

    # Loop through each image pair
    for i in range(len(hr_images)):
        hr_image_path = os.path.join(hr_folder, hr_images[i])
        sr_image_path = os.path.join(sr_folder, sr_images[i])

        # Read HR and SR images
        hr_image = cv2.imread(hr_image_path)
        sr_image = cv2.imread(sr_image_path)

        # Calculate PSNR
        psnr_value = calculate_psnr(hr_image, sr_image)
        psnr_values.append(psnr_value)

        # Display the PSNR value for the current image pair
        print(f'Image: {hr_images[i]} | PSNR: {psnr_value:.4f} dB')

    # Calculate average PSNR
    average_psnr = np.mean(psnr_values)
    print(f'Average PSNR: {average_psnr:.4f} dB')

# Example usage
hr_folder = 'ORIGINAL_X3'  # Replace with your HR folder path
sr_folder = 'WAZIR_CARN_X3'   # Replace with your SR folder path
calculate_metrics(hr_folder, sr_folder)



import os
import cv2
import matplotlib.pyplot as plt

def plot_images(hr_folder, sr_folder):
    # Get lists of image files in both folders
    hr_images = [f for f in os.listdir(hr_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]
    sr_images = [f for f in os.listdir(sr_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]

    # Ensure both folders have the same number of images
    if len(hr_images) != len(sr_images):
        raise ValueError("The number of images in HR and SR folders must be the same.")

    # Set up the plot
    num_images = len(hr_images)
    plt.figure(figsize=(15, 5 * num_images))

    # Loop through each image pair
    for i in range(num_images):
        hr_image_path = os.path.join(hr_folder, hr_images[i])
        sr_image_path = os.path.join(sr_folder, sr_images[i])

        # Read images
        hr_image = cv2.imread(hr_image_path)
        sr_image = cv2.imread(sr_image_path)

        # Convert BGR to RGB (OpenCV loads images in BGR format)
        hr_image = cv2.cvtColor(hr_image, cv2.COLOR_BGR2RGB)
        sr_image = cv2.cvtColor(sr_image, cv2.COLOR_BGR2RGB)

        # Plot HR image
        plt.subplot(num_images, 2, 2 * i + 1)
        plt.imshow(hr_image)
        plt.title(f'High Resolution - {hr_images[i]}')
        plt.axis('off')

        # Plot SR image
        plt.subplot(num_images, 2, 2 * i + 2)
        plt.imshow(sr_image)
        plt.title(f'Super Resolution - {sr_images[i]}')
        plt.axis('off')

    plt.tight_layout()
    plt.show()

# Example usage
hr_folder = 'ORIGINAL_X3'  # Replace with your HR folder path
sr_folder = 'WAZIR_CARN_X3'   # Replace with your SR folder path
plot_images(hr_folder, sr_folder)

# %%
############ CARN-SCALE-4X ############# SET5

# %%
import os
from super_image import CarnModel, ImageLoader
from PIL import Image

def process_images(input_folder, output_folder, model_name='eugenesiow/carn', scale=4):
    # Load the pre-trained model
    model = CarnModel.from_pretrained(model_name, scale=scale)

    # Ensure the output folder exists
    os.makedirs(output_folder, exist_ok=True)

    # Iterate through all images in the input folder
    for filename in os.listdir(input_folder):
        if filename.endswith(('.png', '.jpg', '.jpeg')):  # Check for image file extensions
            # Load the image
            image_path = os.path.join(input_folder, filename)
            print(f'Processing {image_path}...')
            image = Image.open(image_path)

            # Prepare the image for the model
            inputs = ImageLoader.load_image(image)

            # Perform super-resolution
            preds = model(inputs)

            # Save the output image
            output_path = os.path.join(output_folder, f'scaled_{filename}')
            ImageLoader.save_image(preds, output_path)
            print(f'Saved scaled image to {output_path}')

# Example usage
input_folder = 'LR_X4'  # Replace with your input folder path
output_folder = 'WAZIR_CARN_X4'  # Replace with your output folder path
process_images(input_folder, output_folder)


import os
import cv2
import numpy as np

def calculate_psnr(reference, distorted):
    """Calculate PSNR between two images."""
    mse = np.mean((reference - distorted) ** 2)
    if mse == 0:
        return float('inf')  # If MSE is zero, PSNR is infinite
    max_pixel_value = 255.0  # For 8-bit images
    psnr = 20 * np.log10(max_pixel_value / np.sqrt(mse))
    return psnr

def calculate_metrics(hr_folder, sr_folder):
    psnr_values = []

    # Get lists of image files in both folders
    hr_images = [f for f in os.listdir(hr_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]
    sr_images = [f for f in os.listdir(sr_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]

    # Ensure both folders have the same number of images
    if len(hr_images) != len(sr_images):
        raise ValueError("The number of images in HR and SR folders must be the same.")

    # Loop through each image pair
    for i in range(len(hr_images)):
        hr_image_path = os.path.join(hr_folder, hr_images[i])
        sr_image_path = os.path.join(sr_folder, sr_images[i])

        # Read HR and SR images
        hr_image = cv2.imread(hr_image_path)
        sr_image = cv2.imread(sr_image_path)

        # Calculate PSNR
        psnr_value = calculate_psnr(hr_image, sr_image)
        psnr_values.append(psnr_value)

        # Display the PSNR value for the current image pair
        print(f'Image: {hr_images[i]} | PSNR: {psnr_value:.4f} dB')

    # Calculate average PSNR
    average_psnr = np.mean(psnr_values)
    print(f'Average PSNR: {average_psnr:.4f} dB')

# Example usage
hr_folder = 'ORIGINAL_X4'  # Replace with your HR folder path
sr_folder = 'WAZIR_CARN_X4'   # Replace with your SR folder path
calculate_metrics(hr_folder, sr_folder)




#############################################SSIM##########################
import os
import cv2
import numpy as np
from skimage.metrics import structural_similarity as ssim

def calculate_ssim(reference, distorted):
    """Calculate SSIM between two images."""
    if reference.shape != distorted.shape:
        raise ValueError("Reference and distorted images must have the same dimensions.")
    
    # Convert images to grayscale if they are not already
    if len(reference.shape) == 3:
        reference = cv2.cvtColor(reference, cv2.COLOR_BGR2GRAY)
    if len(distorted.shape) == 3:
        distorted = cv2.cvtColor(distorted, cv2.COLOR_BGR2GRAY)

    return ssim(reference, distorted)

def calculate_metrics(hr_folder, sr_folder):
    ssim_values = []

    # Get lists of image files in both folders
    hr_images = [f for f in os.listdir(hr_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]
    sr_images = [f for f in os.listdir(sr_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]

    # Ensure both folders have the same number of images
    if len(hr_images) != len(sr_images):
        raise ValueError("The number of images in HR and SR folders must be the same.")

    # Loop through each image pair
    for i in range(len(hr_images)):
        hr_image_path = os.path.join(hr_folder, hr_images[i])
        sr_image_path = os.path.join(sr_folder, sr_images[i])

        # Read HR and SR images
        hr_image = cv2.imread(hr_image_path)
        sr_image = cv2.imread(sr_image_path)

        # Calculate SSIM
        ssim_value = calculate_ssim(hr_image, sr_image)
        ssim_values.append(ssim_value)

        # Display the SSIM value for the current image pair
        print(f'Image: {hr_images[i]} | SSIM: {ssim_value:.4f}')

    # Calculate average SSIM
    average_ssim = np.mean(ssim_values)
    print(f'Average SSIM: {average_ssim:.4f}')

# Example usage
hr_folder = 'ORIGINAL_X4'  # Replace with your HR folder path
sr_folder = 'WAZIR_CARN_X4'   # Replace with your SR folder path
calculate_metrics(hr_folder, sr_folder)



import os
import cv2
import matplotlib.pyplot as plt

def plot_images(hr_folder, sr_folder):
    # Get lists of image files in both folders
    hr_images = [f for f in os.listdir(hr_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]
    sr_images = [f for f in os.listdir(sr_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]

    # Ensure both folders have the same number of images
    if len(hr_images) != len(sr_images):
        raise ValueError("The number of images in HR and SR folders must be the same.")

    # Set up the plot
    num_images = len(hr_images)
    plt.figure(figsize=(15, 5 * num_images))

    # Loop through each image pair
    for i in range(num_images):
        hr_image_path = os.path.join(hr_folder, hr_images[i])
        sr_image_path = os.path.join(sr_folder, sr_images[i])

        # Read images
        hr_image = cv2.imread(hr_image_path)
        sr_image = cv2.imread(sr_image_path)

        # Convert BGR to RGB (OpenCV loads images in BGR format)
        hr_image = cv2.cvtColor(hr_image, cv2.COLOR_BGR2RGB)
        sr_image = cv2.cvtColor(sr_image, cv2.COLOR_BGR2RGB)

        # Plot HR image
        plt.subplot(num_images, 2, 2 * i + 1)
        plt.imshow(hr_image)
        plt.title(f'High Resolution - {hr_images[i]}')
        plt.axis('off')

        # Plot SR image
        plt.subplot(num_images, 2, 2 * i + 2)
        plt.imshow(sr_image)
        plt.title(f'Super Resolution - {sr_images[i]}')
        plt.axis('off')

    plt.tight_layout()
    plt.show()

# Example usage
hr_folder = 'ORIGINAL_X4'  # Replace with your HR folder path
sr_folder = 'WAZIR_CARN_X4'   # Replace with your SR folder path
plot_images(hr_folder, sr_folder)

# %%
############################# MDSR METTHOD ############################
# !mkdir WAZIR_MDSR_X2
# !mkdir WAZIR_MDSR_X2
# !mkdir WAZIR_MDSR_X2

# %%
import os
from super_image import MdsrModel, ImageLoader
from PIL import Image
import requests

def process_images(input_folder, output_folder, model_name='eugenesiow/mdsr', scale=2):
    # Load the pre-trained model
    model = MdsrModel.from_pretrained(model_name, scale=scale)

    # Ensure the output folder exists
    os.makedirs(output_folder, exist_ok=True)

    # Iterate through all images in the input folder
    for filename in os.listdir(input_folder):
        if filename.endswith(('.png', '.jpg', '.jpeg')):  # Check for image file extensions
            # Load the image
            image_path = os.path.join(input_folder, filename)
            print(f'Processing {image_path}...')
            image = Image.open(image_path)

            # Prepare the image for the model
            inputs = ImageLoader.load_image(image)

            # Perform super-resolution
            preds = model(inputs)

            # Save the output image
            output_path = os.path.join(output_folder, f'scaled_{filename}')
            ImageLoader.save_image(preds, output_path)
            print(f'Saved scaled image to {output_path}')

# Example usage
input_folder = 'LR_X2'  # Replace with your input folder path
output_folder = 'WAZIR_MDSR_X2'  # Replace with your output folder path
process_images(input_folder, output_folder)


import os
import cv2
import numpy as np

def calculate_psnr(reference, distorted):
    """Calculate PSNR between two images."""
    mse = np.mean((reference - distorted) ** 2)
    if mse == 0:
        return float('inf')  # If MSE is zero, PSNR is infinite
    max_pixel_value = 255.0  # For 8-bit images
    psnr = 20 * np.log10(max_pixel_value / np.sqrt(mse))
    return psnr

def calculate_metrics(hr_folder, sr_folder):
    psnr_values = []

    # Get lists of image files in both folders
    hr_images = [f for f in os.listdir(hr_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]
    sr_images = [f for f in os.listdir(sr_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]

    # Ensure both folders have the same number of images
    if len(hr_images) != len(sr_images):
        raise ValueError("The number of images in HR and SR folders must be the same.")

    # Loop through each image pair
    for i in range(len(hr_images)):
        hr_image_path = os.path.join(hr_folder, hr_images[i])
        sr_image_path = os.path.join(sr_folder, sr_images[i])

        # Read HR and SR images
        hr_image = cv2.imread(hr_image_path)
        sr_image = cv2.imread(sr_image_path)

        # Calculate PSNR
        psnr_value = calculate_psnr(hr_image, sr_image)
        psnr_values.append(psnr_value)

        # Display the PSNR value for the current image pair
        print(f'Image: {hr_images[i]} | PSNR: {psnr_value:.4f} dB')

    # Calculate average PSNR
    average_psnr = np.mean(psnr_values)
    print(f'Average PSNR: {average_psnr:.4f} dB')

# Example usage
hr_folder = 'ORIGINAL_X2'  # Replace with your HR folder path
sr_folder = 'WAZIR_MDSR_X2'   # Replace with your SR folder path
calculate_metrics(hr_folder, sr_folder)


#############################################SSIM##########################
import os
import cv2
import numpy as np
from skimage.metrics import structural_similarity as ssim

def calculate_ssim(reference, distorted):
    """Calculate SSIM between two images."""
    if reference.shape != distorted.shape:
        raise ValueError("Reference and distorted images must have the same dimensions.")
    
    # Convert images to grayscale if they are not already
    if len(reference.shape) == 3:
        reference = cv2.cvtColor(reference, cv2.COLOR_BGR2GRAY)
    if len(distorted.shape) == 3:
        distorted = cv2.cvtColor(distorted, cv2.COLOR_BGR2GRAY)

    return ssim(reference, distorted)

def calculate_metrics(hr_folder, sr_folder):
    ssim_values = []

    # Get lists of image files in both folders
    hr_images = [f for f in os.listdir(hr_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]
    sr_images = [f for f in os.listdir(sr_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]

    # Ensure both folders have the same number of images
    if len(hr_images) != len(sr_images):
        raise ValueError("The number of images in HR and SR folders must be the same.")

    # Loop through each image pair
    for i in range(len(hr_images)):
        hr_image_path = os.path.join(hr_folder, hr_images[i])
        sr_image_path = os.path.join(sr_folder, sr_images[i])

        # Read HR and SR images
        hr_image = cv2.imread(hr_image_path)
        sr_image = cv2.imread(sr_image_path)

        # Calculate SSIM
        ssim_value = calculate_ssim(hr_image, sr_image)
        ssim_values.append(ssim_value)

        # Display the SSIM value for the current image pair
        print(f'Image: {hr_images[i]} | SSIM: {ssim_value:.4f}')

    # Calculate average SSIM
    average_ssim = np.mean(ssim_values)
    print(f'Average SSIM: {average_ssim:.4f}')

# Example usage
hr_folder = 'ORIGINAL_X2'  # Replace with your HR folder path
sr_folder = 'WAZIR_MDSR_X2'   # Replace with your SR folder path
calculate_metrics(hr_folder, sr_folder)



import os
import cv2
import matplotlib.pyplot as plt

def plot_images(hr_folder, sr_folder):
    # Get lists of image files in both folders
    hr_images = [f for f in os.listdir(hr_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]
    sr_images = [f for f in os.listdir(sr_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]

    # Ensure both folders have the same number of images
    if len(hr_images) != len(sr_images):
        raise ValueError("The number of images in HR and SR folders must be the same.")

    # Set up the plot
    num_images = len(hr_images)
    plt.figure(figsize=(15, 5 * num_images))

    # Loop through each image pair
    for i in range(num_images):
        hr_image_path = os.path.join(hr_folder, hr_images[i])
        sr_image_path = os.path.join(sr_folder, sr_images[i])

        # Read images
        hr_image = cv2.imread(hr_image_path)
        sr_image = cv2.imread(sr_image_path)

        # Convert BGR to RGB (OpenCV loads images in BGR format)
        hr_image = cv2.cvtColor(hr_image, cv2.COLOR_BGR2RGB)
        sr_image = cv2.cvtColor(sr_image, cv2.COLOR_BGR2RGB)

        # Plot HR image
        plt.subplot(num_images, 2, 2 * i + 1)
        plt.imshow(hr_image)
        plt.title(f'High Resolution - {hr_images[i]}')
        plt.axis('off')

        # Plot SR image
        plt.subplot(num_images, 2, 2 * i + 2)
        plt.imshow(sr_image)
        plt.title(f'Super Resolution - {sr_images[i]}')
        plt.axis('off')

    plt.tight_layout()
    plt.show()

# Example usage
hr_folder = 'ORIGINAL_X2'  # Replace with your HR folder path
sr_folder = 'WAZIR_MDSR_X2'   # Replace with your SR folder path
plot_images(hr_folder, sr_folder)

# %%
import os
from super_image import MdsrModel, ImageLoader
from PIL import Image
import requests

def process_images(input_folder, output_folder, model_name='eugenesiow/mdsr', scale=3):
    # Load the pre-trained model
    model = MdsrModel.from_pretrained(model_name, scale=scale)

    # Ensure the output folder exists
    os.makedirs(output_folder, exist_ok=True)

    # Iterate through all images in the input folder
    for filename in os.listdir(input_folder):
        if filename.endswith(('.png', '.jpg', '.jpeg')):  # Check for image file extensions
            # Load the image
            image_path = os.path.join(input_folder, filename)
            print(f'Processing {image_path}...')
            image = Image.open(image_path)

            # Prepare the image for the model
            inputs = ImageLoader.load_image(image)

            # Perform super-resolution
            preds = model(inputs)

            # Save the output image
            output_path = os.path.join(output_folder, f'scaled_{filename}')
            ImageLoader.save_image(preds, output_path)
            print(f'Saved scaled image to {output_path}')

# Example usage
input_folder = 'LR_X3'  # Replace with your input folder path
output_folder = 'WAZIR_MDSR_X3'  # Replace with your output folder path
process_images(input_folder, output_folder)


import os
import cv2
import numpy as np

def calculate_psnr(reference, distorted):
    """Calculate PSNR between two images."""
    mse = np.mean((reference - distorted) ** 2)
    if mse == 0:
        return float('inf')  # If MSE is zero, PSNR is infinite
    max_pixel_value = 255.0  # For 8-bit images
    psnr = 20 * np.log10(max_pixel_value / np.sqrt(mse))
    return psnr

def calculate_metrics(hr_folder, sr_folder):
    psnr_values = []

    # Get lists of image files in both folders
    hr_images = [f for f in os.listdir(hr_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]
    sr_images = [f for f in os.listdir(sr_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]

    # Ensure both folders have the same number of images
    if len(hr_images) != len(sr_images):
        raise ValueError("The number of images in HR and SR folders must be the same.")

    # Loop through each image pair
    for i in range(len(hr_images)):
        hr_image_path = os.path.join(hr_folder, hr_images[i])
        sr_image_path = os.path.join(sr_folder, sr_images[i])

        # Read HR and SR images
        hr_image = cv2.imread(hr_image_path)
        sr_image = cv2.imread(sr_image_path)

        # Calculate PSNR
        psnr_value = calculate_psnr(hr_image, sr_image)
        psnr_values.append(psnr_value)

        # Display the PSNR value for the current image pair
        print(f'Image: {hr_images[i]} | PSNR: {psnr_value:.4f} dB')

    # Calculate average PSNR
    average_psnr = np.mean(psnr_values)
    print(f'Average PSNR: {average_psnr:.4f} dB')

# Example usage
hr_folder = 'ORIGINAL_X3'  # Replace with your HR folder path
sr_folder = 'WAZIR_MDSR_X3'   # Replace with your SR folder path
calculate_metrics(hr_folder, sr_folder)


#############################################SSIM##########################
import os
import cv2
import numpy as np
from skimage.metrics import structural_similarity as ssim

def calculate_ssim(reference, distorted):
    """Calculate SSIM between two images."""
    if reference.shape != distorted.shape:
        raise ValueError("Reference and distorted images must have the same dimensions.")
    
    # Convert images to grayscale if they are not already
    if len(reference.shape) == 3:
        reference = cv2.cvtColor(reference, cv2.COLOR_BGR2GRAY)
    if len(distorted.shape) == 3:
        distorted = cv2.cvtColor(distorted, cv2.COLOR_BGR2GRAY)

    return ssim(reference, distorted)

def calculate_metrics(hr_folder, sr_folder):
    ssim_values = []

    # Get lists of image files in both folders
    hr_images = [f for f in os.listdir(hr_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]
    sr_images = [f for f in os.listdir(sr_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]

    # Ensure both folders have the same number of images
    if len(hr_images) != len(sr_images):
        raise ValueError("The number of images in HR and SR folders must be the same.")

    # Loop through each image pair
    for i in range(len(hr_images)):
        hr_image_path = os.path.join(hr_folder, hr_images[i])
        sr_image_path = os.path.join(sr_folder, sr_images[i])

        # Read HR and SR images
        hr_image = cv2.imread(hr_image_path)
        sr_image = cv2.imread(sr_image_path)

        # Calculate SSIM
        ssim_value = calculate_ssim(hr_image, sr_image)
        ssim_values.append(ssim_value)

        # Display the SSIM value for the current image pair
        print(f'Image: {hr_images[i]} | SSIM: {ssim_value:.4f}')

    # Calculate average SSIM
    average_ssim = np.mean(ssim_values)
    print(f'Average SSIM: {average_ssim:.4f}')

# Example usage
hr_folder = 'ORIGINAL_X3'  # Replace with your HR folder path
sr_folder = 'WAZIR_MDSR_X3'   # Replace with your SR folder path
calculate_metrics(hr_folder, sr_folder)


import os
import cv2
import matplotlib.pyplot as plt

def plot_images(hr_folder, sr_folder):
    # Get lists of image files in both folders
    hr_images = [f for f in os.listdir(hr_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]
    sr_images = [f for f in os.listdir(sr_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]

    # Ensure both folders have the same number of images
    if len(hr_images) != len(sr_images):
        raise ValueError("The number of images in HR and SR folders must be the same.")

    # Set up the plot
    num_images = len(hr_images)
    plt.figure(figsize=(15, 5 * num_images))

    # Loop through each image pair
    for i in range(num_images):
        hr_image_path = os.path.join(hr_folder, hr_images[i])
        sr_image_path = os.path.join(sr_folder, sr_images[i])

        # Read images
        hr_image = cv2.imread(hr_image_path)
        sr_image = cv2.imread(sr_image_path)

        # Convert BGR to RGB (OpenCV loads images in BGR format)
        hr_image = cv2.cvtColor(hr_image, cv2.COLOR_BGR2RGB)
        sr_image = cv2.cvtColor(sr_image, cv2.COLOR_BGR2RGB)

        # Plot HR image
        plt.subplot(num_images, 2, 2 * i + 1)
        plt.imshow(hr_image)
        plt.title(f'High Resolution - {hr_images[i]}')
        plt.axis('off')

        # Plot SR image
        plt.subplot(num_images, 2, 2 * i + 2)
        plt.imshow(sr_image)
        plt.title(f'Super Resolution - {sr_images[i]}')
        plt.axis('off')

    plt.tight_layout()
    plt.show()

# Example usage
hr_folder = 'ORIGINAL_X3'  # Replace with your HR folder path
sr_folder = 'WAZIR_MDSR_X3'   # Replace with your SR folder path
plot_images(hr_folder, sr_folder)

# %%
import os
from super_image import MdsrModel, ImageLoader
from PIL import Image
import requests

def process_images(input_folder, output_folder, model_name='eugenesiow/mdsr', scale=4):
    # Load the pre-trained model
    model = MdsrModel.from_pretrained(model_name, scale=scale)

    # Ensure the output folder exists
    os.makedirs(output_folder, exist_ok=True)

    # Iterate through all images in the input folder
    for filename in os.listdir(input_folder):
        if filename.endswith(('.png', '.jpg', '.jpeg')):  # Check for image file extensions
            # Load the image
            image_path = os.path.join(input_folder, filename)
            print(f'Processing {image_path}...')
            image = Image.open(image_path)

            # Prepare the image for the model
            inputs = ImageLoader.load_image(image)

            # Perform super-resolution
            preds = model(inputs)

            # Save the output image
            output_path = os.path.join(output_folder, f'scaled_{filename}')
            ImageLoader.save_image(preds, output_path)
            print(f'Saved scaled image to {output_path}')

# Example usage
input_folder = 'LR_X4'  # Replace with your input folder path
output_folder = 'WAZIR_MDSR_X4'  # Replace with your output folder path
process_images(input_folder, output_folder)


import os
import cv2
import numpy as np

def calculate_psnr(reference, distorted):
    """Calculate PSNR between two images."""
    mse = np.mean((reference - distorted) ** 2)
    if mse == 0:
        return float('inf')  # If MSE is zero, PSNR is infinite
    max_pixel_value = 255.0  # For 8-bit images
    psnr = 20 * np.log10(max_pixel_value / np.sqrt(mse))
    return psnr

def calculate_metrics(hr_folder, sr_folder):
    psnr_values = []

    # Get lists of image files in both folders
    hr_images = [f for f in os.listdir(hr_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]
    sr_images = [f for f in os.listdir(sr_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]

    # Ensure both folders have the same number of images
    if len(hr_images) != len(sr_images):
        raise ValueError("The number of images in HR and SR folders must be the same.")

    # Loop through each image pair
    for i in range(len(hr_images)):
        hr_image_path = os.path.join(hr_folder, hr_images[i])
        sr_image_path = os.path.join(sr_folder, sr_images[i])

        # Read HR and SR images
        hr_image = cv2.imread(hr_image_path)
        sr_image = cv2.imread(sr_image_path)

        # Calculate PSNR
        psnr_value = calculate_psnr(hr_image, sr_image)
        psnr_values.append(psnr_value)

        # Display the PSNR value for the current image pair
        print(f'Image: {hr_images[i]} | PSNR: {psnr_value:.4f} dB')

    # Calculate average PSNR
    average_psnr = np.mean(psnr_values)
    print(f'Average PSNR: {average_psnr:.4f} dB')

# Example usage
hr_folder = 'ORIGINAL_X4'  # Replace with your HR folder path
sr_folder = 'WAZIR_MDSR_X4'   # Replace with your SR folder path
calculate_metrics(hr_folder, sr_folder)


#############################################SSIM##########################
import os
import cv2
import numpy as np
from skimage.metrics import structural_similarity as ssim

def calculate_ssim(reference, distorted):
    """Calculate SSIM between two images."""
    if reference.shape != distorted.shape:
        raise ValueError("Reference and distorted images must have the same dimensions.")
    
    # Convert images to grayscale if they are not already
    if len(reference.shape) == 3:
        reference = cv2.cvtColor(reference, cv2.COLOR_BGR2GRAY)
    if len(distorted.shape) == 3:
        distorted = cv2.cvtColor(distorted, cv2.COLOR_BGR2GRAY)

    return ssim(reference, distorted)

def calculate_metrics(hr_folder, sr_folder):
    ssim_values = []

    # Get lists of image files in both folders
    hr_images = [f for f in os.listdir(hr_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]
    sr_images = [f for f in os.listdir(sr_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]

    # Ensure both folders have the same number of images
    if len(hr_images) != len(sr_images):
        raise ValueError("The number of images in HR and SR folders must be the same.")

    # Loop through each image pair
    for i in range(len(hr_images)):
        hr_image_path = os.path.join(hr_folder, hr_images[i])
        sr_image_path = os.path.join(sr_folder, sr_images[i])

        # Read HR and SR images
        hr_image = cv2.imread(hr_image_path)
        sr_image = cv2.imread(sr_image_path)

        # Calculate SSIM
        ssim_value = calculate_ssim(hr_image, sr_image)
        ssim_values.append(ssim_value)

        # Display the SSIM value for the current image pair
        print(f'Image: {hr_images[i]} | SSIM: {ssim_value:.4f}')

    # Calculate average SSIM
    average_ssim = np.mean(ssim_values)
    print(f'Average SSIM: {average_ssim:.4f}')

# Example usage
hr_folder = 'ORIGINAL_X4'  # Replace with your HR folder path
sr_folder = 'WAZIR_MDSR_X4'   # Replace with your SR folder path
calculate_metrics(hr_folder, sr_folder)




import os
import cv2
import matplotlib.pyplot as plt

def plot_images(hr_folder, sr_folder):
    # Get lists of image files in both folders
    hr_images = [f for f in os.listdir(hr_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]
    sr_images = [f for f in os.listdir(sr_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]

    # Ensure both folders have the same number of images
    if len(hr_images) != len(sr_images):
        raise ValueError("The number of images in HR and SR folders must be the same.")

    # Set up the plot
    num_images = len(hr_images)
    plt.figure(figsize=(15, 5 * num_images))

    # Loop through each image pair
    for i in range(num_images):
        hr_image_path = os.path.join(hr_folder, hr_images[i])
        sr_image_path = os.path.join(sr_folder, sr_images[i])

        # Read images
        hr_image = cv2.imread(hr_image_path)
        sr_image = cv2.imread(sr_image_path)

        # Convert BGR to RGB (OpenCV loads images in BGR format)
        hr_image = cv2.cvtColor(hr_image, cv2.COLOR_BGR2RGB)
        sr_image = cv2.cvtColor(sr_image, cv2.COLOR_BGR2RGB)

        # Plot HR image
        plt.subplot(num_images, 2, 2 * i + 1)
        plt.imshow(hr_image)
        plt.title(f'High Resolution - {hr_images[i]}')
        plt.axis('off')

        # Plot SR image
        plt.subplot(num_images, 2, 2 * i + 2)
        plt.imshow(sr_image)
        plt.title(f'Super Resolution - {sr_images[i]}')
        plt.axis('off')

    plt.tight_layout()
    plt.show()

# Example usage
hr_folder = 'ORIGINAL_X4'  # Replace with your HR folder path
sr_folder = 'WAZIR_MDSR_X4'   # Replace with your SR folder path
plot_images(hr_folder, sr_folder)

# %%
########################### EDSR METHOD################

# %%
# !mkdir WAZIR_EDSR_X2
# !mkdir WAZIR_EDSR_X3
# !mkdir WAZIR_EDSR_X4

# %%
from super_image import EdsrModel, ImageLoader
from PIL import Image
import requests
import os

def process_images(input_folder, output_folder, model_name='eugenesiow/edsr', scale=2):
    # Load the pre-trained model
    model = EdsrModel.from_pretrained(model_name, scale=scale)

    # Ensure the output folder exists
    #os.makedirs(output_folder, exist_ok=True)

    # Iterate through all images in the input folder
    for filename in os.listdir(input_folder):
        if filename.endswith(('.png', '.jpg', '.jpeg')):  # Check for image file extensions
            # Load the image
            image_path = os.path.join(input_folder, filename)
            print(f'Processing {image_path}...')
            image = Image.open(image_path)

            # Prepare the image for the model
            inputs = ImageLoader.load_image(image)

            # Perform super-resolution
            preds = model(inputs)

            # Save the output image
            output_path = os.path.join(output_folder, f'scaled_{filename}')
            ImageLoader.save_image(preds, output_path)
            print(f'Saved scaled image to {output_path}')

# Example usage
input_folder = 'LR_X2'  # Replace with your input folder path
output_folder = 'WAZIR_EDSR_X2'  # Replace with your output folder path
process_images(input_folder, output_folder)


import os
import cv2
import numpy as np

def calculate_psnr(reference, distorted):
    """Calculate PSNR between two images."""
    mse = np.mean((reference - distorted) ** 2)
    if mse == 0:
        return float('inf')  # If MSE is zero, PSNR is infinite
    max_pixel_value = 255.0  # For 8-bit images
    psnr = 20 * np.log10(max_pixel_value / np.sqrt(mse))
    return psnr

def calculate_metrics(hr_folder, sr_folder):
    psnr_values = []

    # Get lists of image files in both folders
    hr_images = [f for f in os.listdir(hr_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]
    sr_images = [f for f in os.listdir(sr_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]

    # Ensure both folders have the same number of images
    if len(hr_images) != len(sr_images):
        raise ValueError("The number of images in HR and SR folders must be the same.")

    # Loop through each image pair
    for i in range(len(hr_images)):
        hr_image_path = os.path.join(hr_folder, hr_images[i])
        sr_image_path = os.path.join(sr_folder, sr_images[i])

        # Read HR and SR images
        hr_image = cv2.imread(hr_image_path)
        sr_image = cv2.imread(sr_image_path)

        # Calculate PSNR
        psnr_value = calculate_psnr(hr_image, sr_image)
        psnr_values.append(psnr_value)

        # Display the PSNR value for the current image pair
        print(f'Image: {hr_images[i]} | PSNR: {psnr_value:.4f} dB')

    # Calculate average PSNR
    average_psnr = np.mean(psnr_values)
    print(f'Average PSNR: {average_psnr:.4f} dB')

# Example usage
hr_folder = 'ORIGINAL_X2'  # Replace with your HR folder path
sr_folder = 'WAZIR_EDSR_X2'   # Replace with your SR folder path
calculate_metrics(hr_folder, sr_folder)


#############################################SSIM##########################
import os
import cv2
import numpy as np
from skimage.metrics import structural_similarity as ssim

def calculate_ssim(reference, distorted):
    """Calculate SSIM between two images."""
    if reference.shape != distorted.shape:
        raise ValueError("Reference and distorted images must have the same dimensions.")
    
    # Convert images to grayscale if they are not already
    if len(reference.shape) == 3:
        reference = cv2.cvtColor(reference, cv2.COLOR_BGR2GRAY)
    if len(distorted.shape) == 3:
        distorted = cv2.cvtColor(distorted, cv2.COLOR_BGR2GRAY)

    return ssim(reference, distorted)

def calculate_metrics(hr_folder, sr_folder):
    ssim_values = []

    # Get lists of image files in both folders
    hr_images = [f for f in os.listdir(hr_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]
    sr_images = [f for f in os.listdir(sr_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]

    # Ensure both folders have the same number of images
    if len(hr_images) != len(sr_images):
        raise ValueError("The number of images in HR and SR folders must be the same.")

    # Loop through each image pair
    for i in range(len(hr_images)):
        hr_image_path = os.path.join(hr_folder, hr_images[i])
        sr_image_path = os.path.join(sr_folder, sr_images[i])

        # Read HR and SR images
        hr_image = cv2.imread(hr_image_path)
        sr_image = cv2.imread(sr_image_path)

        # Calculate SSIM
        ssim_value = calculate_ssim(hr_image, sr_image)
        ssim_values.append(ssim_value)

        # Display the SSIM value for the current image pair
        print(f'Image: {hr_images[i]} | SSIM: {ssim_value:.4f}')

    # Calculate average SSIM
    average_ssim = np.mean(ssim_values)
    print(f'Average SSIM: {average_ssim:.4f}')

# Example usage
hr_folder = 'ORIGINAL_X2'  # Replace with your HR folder path
sr_folder = 'WAZIR_EDSR_X2'   # Replace with your SR folder path
calculate_metrics(hr_folder, sr_folder)



import os
import cv2
import matplotlib.pyplot as plt

def plot_images(hr_folder, sr_folder):
    # Get lists of image files in both folders
    hr_images = [f for f in os.listdir(hr_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]
    sr_images = [f for f in os.listdir(sr_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]

    # Ensure both folders have the same number of images
    if len(hr_images) != len(sr_images):
        raise ValueError("The number of images in HR and SR folders must be the same.")

    # Set up the plot
    num_images = len(hr_images)
    plt.figure(figsize=(15, 5 * num_images))

    # Loop through each image pair
    for i in range(num_images):
        hr_image_path = os.path.join(hr_folder, hr_images[i])
        sr_image_path = os.path.join(sr_folder, sr_images[i])

        # Read images
        hr_image = cv2.imread(hr_image_path)
        sr_image = cv2.imread(sr_image_path)

        # Convert BGR to RGB (OpenCV loads images in BGR format)
        hr_image = cv2.cvtColor(hr_image, cv2.COLOR_BGR2RGB)
        sr_image = cv2.cvtColor(sr_image, cv2.COLOR_BGR2RGB)

        # Plot HR image
        plt.subplot(num_images, 2, 2 * i + 1)
        plt.imshow(hr_image)
        plt.title(f'High Resolution - {hr_images[i]}')
        plt.axis('off')

        # Plot SR image
        plt.subplot(num_images, 2, 2 * i + 2)
        plt.imshow(sr_image)
        plt.title(f'Super Resolution - {sr_images[i]}')
        plt.axis('off')

    plt.tight_layout()
    plt.show()

# Example usage
hr_folder = 'ORIGINAL_X2'  # Replace with your HR folder path
sr_folder = 'WAZIR_EDSR_X2'   # Replace with your SR folder path
plot_images(hr_folder, sr_folder)

# %%
#################### EDSR SCALE 3 ####################

# %%
from super_image import EdsrModel, ImageLoader
from PIL import Image
import requests
import os

def process_images(input_folder, output_folder, model_name='eugenesiow/edsr', scale=3):
    # Load the pre-trained model
    model = EdsrModel.from_pretrained(model_name, scale=scale)

    # Ensure the output folder exists
    #os.makedirs(output_folder, exist_ok=True)

    # Iterate through all images in the input folder
    for filename in os.listdir(input_folder):
        if filename.endswith(('.png', '.jpg', '.jpeg')):  # Check for image file extensions
            # Load the image
            image_path = os.path.join(input_folder, filename)
            print(f'Processing {image_path}...')
            image = Image.open(image_path)

            # Prepare the image for the model
            inputs = ImageLoader.load_image(image)

            # Perform super-resolution
            preds = model(inputs)

            # Save the output image
            output_path = os.path.join(output_folder, f'scaled_{filename}')
            ImageLoader.save_image(preds, output_path)
            print(f'Saved scaled image to {output_path}')

# Example usage
input_folder = 'LR_X3'  # Replace with your input folder path
output_folder = 'WAZIR_EDSR_X3'  # Replace with your output folder path
process_images(input_folder, output_folder)


import os
import cv2
import numpy as np

def calculate_psnr(reference, distorted):
    """Calculate PSNR between two images."""
    mse = np.mean((reference - distorted) ** 2)
    if mse == 0:
        return float('inf')  # If MSE is zero, PSNR is infinite
    max_pixel_value = 255.0  # For 8-bit images
    psnr = 20 * np.log10(max_pixel_value / np.sqrt(mse))
    return psnr

def calculate_metrics(hr_folder, sr_folder):
    psnr_values = []

    # Get lists of image files in both folders
    hr_images = [f for f in os.listdir(hr_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]
    sr_images = [f for f in os.listdir(sr_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]

    # Ensure both folders have the same number of images
    if len(hr_images) != len(sr_images):
        raise ValueError("The number of images in HR and SR folders must be the same.")

    # Loop through each image pair
    for i in range(len(hr_images)):
        hr_image_path = os.path.join(hr_folder, hr_images[i])
        sr_image_path = os.path.join(sr_folder, sr_images[i])

        # Read HR and SR images
        hr_image = cv2.imread(hr_image_path)
        sr_image = cv2.imread(sr_image_path)

        # Calculate PSNR
        psnr_value = calculate_psnr(hr_image, sr_image)
        psnr_values.append(psnr_value)

        # Display the PSNR value for the current image pair
        print(f'Image: {hr_images[i]} | PSNR: {psnr_value:.4f} dB')

    # Calculate average PSNR
    average_psnr = np.mean(psnr_values)
    print(f'Average PSNR: {average_psnr:.4f} dB')

# Example usage
hr_folder = 'ORIGINAL_X3'  # Replace with your HR folder path
sr_folder = 'WAZIR_EDSR_X3'   # Replace with your SR folder path
calculate_metrics(hr_folder, sr_folder)


#############################################SSIM##########################
import os
import cv2
import numpy as np
from skimage.metrics import structural_similarity as ssim

def calculate_ssim(reference, distorted):
    """Calculate SSIM between two images."""
    if reference.shape != distorted.shape:
        raise ValueError("Reference and distorted images must have the same dimensions.")
    
    # Convert images to grayscale if they are not already
    if len(reference.shape) == 3:
        reference = cv2.cvtColor(reference, cv2.COLOR_BGR2GRAY)
    if len(distorted.shape) == 3:
        distorted = cv2.cvtColor(distorted, cv2.COLOR_BGR2GRAY)

    return ssim(reference, distorted)

def calculate_metrics(hr_folder, sr_folder):
    ssim_values = []

    # Get lists of image files in both folders
    hr_images = [f for f in os.listdir(hr_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]
    sr_images = [f for f in os.listdir(sr_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]

    # Ensure both folders have the same number of images
    if len(hr_images) != len(sr_images):
        raise ValueError("The number of images in HR and SR folders must be the same.")

    # Loop through each image pair
    for i in range(len(hr_images)):
        hr_image_path = os.path.join(hr_folder, hr_images[i])
        sr_image_path = os.path.join(sr_folder, sr_images[i])

        # Read HR and SR images
        hr_image = cv2.imread(hr_image_path)
        sr_image = cv2.imread(sr_image_path)

        # Calculate SSIM
        ssim_value = calculate_ssim(hr_image, sr_image)
        ssim_values.append(ssim_value)

        # Display the SSIM value for the current image pair
        print(f'Image: {hr_images[i]} | SSIM: {ssim_value:.4f}')

    # Calculate average SSIM
    average_ssim = np.mean(ssim_values)
    print(f'Average SSIM: {average_ssim:.4f}')

# Example usage
hr_folder = 'ORIGINAL_X3'  # Replace with your HR folder path
sr_folder = 'WAZIR_EDSR_X3'   # Replace with your SR folder path
calculate_metrics(hr_folder, sr_folder)



import os
import cv2
import matplotlib.pyplot as plt

def plot_images(hr_folder, sr_folder):
    # Get lists of image files in both folders
    hr_images = [f for f in os.listdir(hr_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]
    sr_images = [f for f in os.listdir(sr_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]

    # Ensure both folders have the same number of images
    if len(hr_images) != len(sr_images):
        raise ValueError("The number of images in HR and SR folders must be the same.")

    # Set up the plot
    num_images = len(hr_images)
    plt.figure(figsize=(15, 5 * num_images))

    # Loop through each image pair
    for i in range(num_images):
        hr_image_path = os.path.join(hr_folder, hr_images[i])
        sr_image_path = os.path.join(sr_folder, sr_images[i])

        # Read images
        hr_image = cv2.imread(hr_image_path)
        sr_image = cv2.imread(sr_image_path)

        # Convert BGR to RGB (OpenCV loads images in BGR format)
        hr_image = cv2.cvtColor(hr_image, cv2.COLOR_BGR2RGB)
        sr_image = cv2.cvtColor(sr_image, cv2.COLOR_BGR2RGB)

        # Plot HR image
        plt.subplot(num_images, 2, 2 * i + 1)
        plt.imshow(hr_image)
        plt.title(f'High Resolution - {hr_images[i]}')
        plt.axis('off')

        # Plot SR image
        plt.subplot(num_images, 2, 2 * i + 2)
        plt.imshow(sr_image)
        plt.title(f'Super Resolution - {sr_images[i]}')
        plt.axis('off')

    plt.tight_layout()
    plt.show()

# Example usage
hr_folder = 'ORIGINAL_X3'  # Replace with your HR folder path
sr_folder = 'WAZIR_EDSR_X3'   # Replace with your SR folder path
plot_images(hr_folder, sr_folder)

# %%
######################## EDSR X4 ##########################

# %%
from super_image import EdsrModel, ImageLoader
from PIL import Image
import requests
import os

def process_images(input_folder, output_folder, model_name='eugenesiow/edsr', scale=4):
    # Load the pre-trained model
    model = EdsrModel.from_pretrained(model_name, scale=scale)

    # Ensure the output folder exists
    #os.makedirs(output_folder, exist_ok=True)

    # Iterate through all images in the input folder
    for filename in os.listdir(input_folder):
        if filename.endswith(('.png', '.jpg', '.jpeg')):  # Check for image file extensions
            # Load the image
            image_path = os.path.join(input_folder, filename)
            print(f'Processing {image_path}...')
            image = Image.open(image_path)

            # Prepare the image for the model
            inputs = ImageLoader.load_image(image)

            # Perform super-resolution
            preds = model(inputs)

            # Save the output image
            output_path = os.path.join(output_folder, f'scaled_{filename}')
            ImageLoader.save_image(preds, output_path)
            print(f'Saved scaled image to {output_path}')

# Example usage
input_folder = 'LR_X4'  # Replace with your input folder path
output_folder = 'WAZIR_EDSR_X4'  # Replace with your output folder path
process_images(input_folder, output_folder)


import os
import cv2
import numpy as np

def calculate_psnr(reference, distorted):
    """Calculate PSNR between two images."""
    mse = np.mean((reference - distorted) ** 2)
    if mse == 0:
        return float('inf')  # If MSE is zero, PSNR is infinite
    max_pixel_value = 255.0  # For 8-bit images
    psnr = 20 * np.log10(max_pixel_value / np.sqrt(mse))
    return psnr

def calculate_metrics(hr_folder, sr_folder):
    psnr_values = []

    # Get lists of image files in both folders
    hr_images = [f for f in os.listdir(hr_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]
    sr_images = [f for f in os.listdir(sr_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]

    # Ensure both folders have the same number of images
    if len(hr_images) != len(sr_images):
        raise ValueError("The number of images in HR and SR folders must be the same.")

    # Loop through each image pair
    for i in range(len(hr_images)):
        hr_image_path = os.path.join(hr_folder, hr_images[i])
        sr_image_path = os.path.join(sr_folder, sr_images[i])

        # Read HR and SR images
        hr_image = cv2.imread(hr_image_path)
        sr_image = cv2.imread(sr_image_path)

        # Calculate PSNR
        psnr_value = calculate_psnr(hr_image, sr_image)
        psnr_values.append(psnr_value)

        # Display the PSNR value for the current image pair
        print(f'Image: {hr_images[i]} | PSNR: {psnr_value:.4f} dB')

    # Calculate average PSNR
    average_psnr = np.mean(psnr_values)
    print(f'Average PSNR: {average_psnr:.4f} dB')

# Example usage
hr_folder = 'ORIGINAL_X4'  # Replace with your HR folder path
sr_folder = 'WAZIR_EDSR_X4'   # Replace with your SR folder path
calculate_metrics(hr_folder, sr_folder)


#############################################SSIM##########################
import os
import cv2
import numpy as np
from skimage.metrics import structural_similarity as ssim

def calculate_ssim(reference, distorted):
    """Calculate SSIM between two images."""
    if reference.shape != distorted.shape:
        raise ValueError("Reference and distorted images must have the same dimensions.")
    
    # Convert images to grayscale if they are not already
    if len(reference.shape) == 3:
        reference = cv2.cvtColor(reference, cv2.COLOR_BGR2GRAY)
    if len(distorted.shape) == 3:
        distorted = cv2.cvtColor(distorted, cv2.COLOR_BGR2GRAY)

    return ssim(reference, distorted)

def calculate_metrics(hr_folder, sr_folder):
    ssim_values = []

    # Get lists of image files in both folders
    hr_images = [f for f in os.listdir(hr_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]
    sr_images = [f for f in os.listdir(sr_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]

    # Ensure both folders have the same number of images
    if len(hr_images) != len(sr_images):
        raise ValueError("The number of images in HR and SR folders must be the same.")

    # Loop through each image pair
    for i in range(len(hr_images)):
        hr_image_path = os.path.join(hr_folder, hr_images[i])
        sr_image_path = os.path.join(sr_folder, sr_images[i])

        # Read HR and SR images
        hr_image = cv2.imread(hr_image_path)
        sr_image = cv2.imread(sr_image_path)

        # Calculate SSIM
        ssim_value = calculate_ssim(hr_image, sr_image)
        ssim_values.append(ssim_value)

        # Display the SSIM value for the current image pair
        print(f'Image: {hr_images[i]} | SSIM: {ssim_value:.4f}')

    # Calculate average SSIM
    average_ssim = np.mean(ssim_values)
    print(f'Average SSIM: {average_ssim:.4f}')

# Example usage
hr_folder = 'ORIGINAL_X4'  # Replace with your HR folder path
sr_folder = 'WAZIR_EDSR_X4'   # Replace with your SR folder path
calculate_metrics(hr_folder, sr_folder)



import os
import cv2
import matplotlib.pyplot as plt

def plot_images(hr_folder, sr_folder):
    # Get lists of image files in both folders
    hr_images = [f for f in os.listdir(hr_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]
    sr_images = [f for f in os.listdir(sr_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]

    # Ensure both folders have the same number of images
    if len(hr_images) != len(sr_images):
        raise ValueError("The number of images in HR and SR folders must be the same.")

    # Set up the plot
    num_images = len(hr_images)
    plt.figure(figsize=(15, 5 * num_images))

    # Loop through each image pair
    for i in range(num_images):
        hr_image_path = os.path.join(hr_folder, hr_images[i])
        sr_image_path = os.path.join(sr_folder, sr_images[i])

        # Read images
        hr_image = cv2.imread(hr_image_path)
        sr_image = cv2.imread(sr_image_path)

        # Convert BGR to RGB (OpenCV loads images in BGR format)
        hr_image = cv2.cvtColor(hr_image, cv2.COLOR_BGR2RGB)
        sr_image = cv2.cvtColor(sr_image, cv2.COLOR_BGR2RGB)

        # Plot HR image
        plt.subplot(num_images, 2, 2 * i + 1)
        plt.imshow(hr_image)
        plt.title(f'High Resolution - {hr_images[i]}')
        plt.axis('off')

        # Plot SR image
        plt.subplot(num_images, 2, 2 * i + 2)
        plt.imshow(sr_image)
        plt.title(f'Super Resolution - {sr_images[i]}')
        plt.axis('off')

    plt.tight_layout()
    plt.show()

# Example usage
hr_folder = 'ORIGINAL_X4'  # Replace with your HR folder path
sr_folder = 'WAZIR_EDSR_X4'   # Replace with your SR folder path
plot_images(hr_folder, sr_folder)

# %%
########################### PAN METHODS ################################

# %%
# !mkdir WAZIR_PAN_X2
# !mkdir WAZIR_PAN_X3
# !mkdir WAZIR_PAN_X4

# %%
from super_image import PanModel, ImageLoader
from PIL import Image
import requests

def process_images(input_folder, output_folder, model_name='eugenesiow/pan', scale=2):
    # Load the pre-trained model
    model = PanModel.from_pretrained(model_name, scale=scale)

    # Ensure the output folder exists
    #os.makedirs(output_folder, exist_ok=True)

    # Iterate through all images in the input folder
    for filename in os.listdir(input_folder):
        if filename.endswith(('.png', '.jpg', '.jpeg')):  # Check for image file extensions
            # Load the image
            image_path = os.path.join(input_folder, filename)
            print(f'Processing {image_path}...')
            image = Image.open(image_path)

            # Prepare the image for the model
            inputs = ImageLoader.load_image(image)

            # Perform super-resolution
            preds = model(inputs)

            # Save the output image
            output_path = os.path.join(output_folder, f'scaled_{filename}')
            ImageLoader.save_image(preds, output_path)
            print(f'Saved scaled image to {output_path}')

# Example usage
input_folder = 'LR_X2'  # Replace with your input folder path
output_folder = 'WAZIR_PAN_X2'  # Replace with your output folder path
process_images(input_folder, output_folder)


import os
import cv2
import numpy as np

def calculate_psnr(reference, distorted):
    """Calculate PSNR between two images."""
    mse = np.mean((reference - distorted) ** 2)
    if mse == 0:
        return float('inf')  # If MSE is zero, PSNR is infinite
    max_pixel_value = 255.0  # For 8-bit images
    psnr = 20 * np.log10(max_pixel_value / np.sqrt(mse))
    return psnr

def calculate_metrics(hr_folder, sr_folder):
    psnr_values = []

    # Get lists of image files in both folders
    hr_images = [f for f in os.listdir(hr_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]
    sr_images = [f for f in os.listdir(sr_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]

    # Ensure both folders have the same number of images
    if len(hr_images) != len(sr_images):
        raise ValueError("The number of images in HR and SR folders must be the same.")

    # Loop through each image pair
    for i in range(len(hr_images)):
        hr_image_path = os.path.join(hr_folder, hr_images[i])
        sr_image_path = os.path.join(sr_folder, sr_images[i])

        # Read HR and SR images
        hr_image = cv2.imread(hr_image_path)
        sr_image = cv2.imread(sr_image_path)

        # Calculate PSNR
        psnr_value = calculate_psnr(hr_image, sr_image)
        psnr_values.append(psnr_value)

        # Display the PSNR value for the current image pair
        print(f'Image: {hr_images[i]} | PSNR: {psnr_value:.4f} dB')

    # Calculate average PSNR
    average_psnr = np.mean(psnr_values)
    print(f'Average PSNR: {average_psnr:.4f} dB')

# Example usage
hr_folder = 'ORIGINAL_X2'  # Replace with your HR folder path
sr_folder = 'WAZIR_PAN_X2'   # Replace with your SR folder path
calculate_metrics(hr_folder, sr_folder)


#############################################SSIM##########################
import os
import cv2
import numpy as np
from skimage.metrics import structural_similarity as ssim

def calculate_ssim(reference, distorted):
    """Calculate SSIM between two images."""
    if reference.shape != distorted.shape:
        raise ValueError("Reference and distorted images must have the same dimensions.")
    
    # Convert images to grayscale if they are not already
    if len(reference.shape) == 3:
        reference = cv2.cvtColor(reference, cv2.COLOR_BGR2GRAY)
    if len(distorted.shape) == 3:
        distorted = cv2.cvtColor(distorted, cv2.COLOR_BGR2GRAY)

    return ssim(reference, distorted)

def calculate_metrics(hr_folder, sr_folder):
    ssim_values = []

    # Get lists of image files in both folders
    hr_images = [f for f in os.listdir(hr_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]
    sr_images = [f for f in os.listdir(sr_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]

    # Ensure both folders have the same number of images
    if len(hr_images) != len(sr_images):
        raise ValueError("The number of images in HR and SR folders must be the same.")

    # Loop through each image pair
    for i in range(len(hr_images)):
        hr_image_path = os.path.join(hr_folder, hr_images[i])
        sr_image_path = os.path.join(sr_folder, sr_images[i])

        # Read HR and SR images
        hr_image = cv2.imread(hr_image_path)
        sr_image = cv2.imread(sr_image_path)

        # Calculate SSIM
        ssim_value = calculate_ssim(hr_image, sr_image)
        ssim_values.append(ssim_value)

        # Display the SSIM value for the current image pair
        print(f'Image: {hr_images[i]} | SSIM: {ssim_value:.4f}')

    # Calculate average SSIM
    average_ssim = np.mean(ssim_values)
    print(f'Average SSIM: {average_ssim:.4f}')

# Example usage
hr_folder = 'ORIGINAL_X2'  # Replace with your HR folder path
sr_folder = 'WAZIR_PAN_X2'   # Replace with your SR folder path
calculate_metrics(hr_folder, sr_folder)



import os
import cv2
import matplotlib.pyplot as plt

def plot_images(hr_folder, sr_folder):
    # Get lists of image files in both folders
    hr_images = [f for f in os.listdir(hr_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]
    sr_images = [f for f in os.listdir(sr_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]

    # Ensure both folders have the same number of images
    if len(hr_images) != len(sr_images):
        raise ValueError("The number of images in HR and SR folders must be the same.")

    # Set up the plot
    num_images = len(hr_images)
    plt.figure(figsize=(15, 5 * num_images))

    # Loop through each image pair
    for i in range(num_images):
        hr_image_path = os.path.join(hr_folder, hr_images[i])
        sr_image_path = os.path.join(sr_folder, sr_images[i])

        # Read images
        hr_image = cv2.imread(hr_image_path)
        sr_image = cv2.imread(sr_image_path)

        # Convert BGR to RGB (OpenCV loads images in BGR format)
        hr_image = cv2.cvtColor(hr_image, cv2.COLOR_BGR2RGB)
        sr_image = cv2.cvtColor(sr_image, cv2.COLOR_BGR2RGB)

        # Plot HR image
        plt.subplot(num_images, 2, 2 * i + 1)
        plt.imshow(hr_image)
        plt.title(f'High Resolution - {hr_images[i]}')
        plt.axis('off')

        # Plot SR image
        plt.subplot(num_images, 2, 2 * i + 2)
        plt.imshow(sr_image)
        plt.title(f'Super Resolution - {sr_images[i]}')
        plt.axis('off')

    plt.tight_layout()
    plt.show()

# Example usage
hr_folder = 'ORIGINAL_X2'  # Replace with your HR folder path
sr_folder = 'WAZIR_PAN_X2'   # Replace with your SR folder path
plot_images(hr_folder, sr_folder)

# %%
################### PAN SCALE 3##############################

# %%
from super_image import PanModel, ImageLoader
from PIL import Image
import requests

def process_images(input_folder, output_folder, model_name='eugenesiow/pan', scale=3):
    # Load the pre-trained model
    model = PanModel.from_pretrained(model_name, scale=scale)

    # Ensure the output folder exists
    #os.makedirs(output_folder, exist_ok=True)

    # Iterate through all images in the input folder
    for filename in os.listdir(input_folder):
        if filename.endswith(('.png', '.jpg', '.jpeg')):  # Check for image file extensions
            # Load the image
            image_path = os.path.join(input_folder, filename)
            print(f'Processing {image_path}...')
            image = Image.open(image_path)

            # Prepare the image for the model
            inputs = ImageLoader.load_image(image)

            # Perform super-resolution
            preds = model(inputs)

            # Save the output image
            output_path = os.path.join(output_folder, f'scaled_{filename}')
            ImageLoader.save_image(preds, output_path)
            print(f'Saved scaled image to {output_path}')

# Example usage
input_folder = 'LR_X3'  # Replace with your input folder path
output_folder = 'WAZIR_PAN_X3'  # Replace with your output folder path
process_images(input_folder, output_folder)


import os
import cv2
import numpy as np

def calculate_psnr(reference, distorted):
    """Calculate PSNR between two images."""
    mse = np.mean((reference - distorted) ** 2)
    if mse == 0:
        return float('inf')  # If MSE is zero, PSNR is infinite
    max_pixel_value = 255.0  # For 8-bit images
    psnr = 20 * np.log10(max_pixel_value / np.sqrt(mse))
    return psnr

def calculate_metrics(hr_folder, sr_folder):
    psnr_values = []

    # Get lists of image files in both folders
    hr_images = [f for f in os.listdir(hr_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]
    sr_images = [f for f in os.listdir(sr_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]

    # Ensure both folders have the same number of images
    if len(hr_images) != len(sr_images):
        raise ValueError("The number of images in HR and SR folders must be the same.")

    # Loop through each image pair
    for i in range(len(hr_images)):
        hr_image_path = os.path.join(hr_folder, hr_images[i])
        sr_image_path = os.path.join(sr_folder, sr_images[i])

        # Read HR and SR images
        hr_image = cv2.imread(hr_image_path)
        sr_image = cv2.imread(sr_image_path)

        # Calculate PSNR
        psnr_value = calculate_psnr(hr_image, sr_image)
        psnr_values.append(psnr_value)

        # Display the PSNR value for the current image pair
        print(f'Image: {hr_images[i]} | PSNR: {psnr_value:.4f} dB')

    # Calculate average PSNR
    average_psnr = np.mean(psnr_values)
    print(f'Average PSNR: {average_psnr:.4f} dB')

# Example usage
hr_folder = 'ORIGINAL_X3'  # Replace with your HR folder path
sr_folder = 'WAZIR_PAN_X3'   # Replace with your SR folder path
calculate_metrics(hr_folder, sr_folder)


#############################################SSIM##########################
import os
import cv2
import numpy as np
from skimage.metrics import structural_similarity as ssim

def calculate_ssim(reference, distorted):
    """Calculate SSIM between two images."""
    if reference.shape != distorted.shape:
        raise ValueError("Reference and distorted images must have the same dimensions.")
    
    # Convert images to grayscale if they are not already
    if len(reference.shape) == 3:
        reference = cv2.cvtColor(reference, cv2.COLOR_BGR2GRAY)
    if len(distorted.shape) == 3:
        distorted = cv2.cvtColor(distorted, cv2.COLOR_BGR2GRAY)

    return ssim(reference, distorted)

def calculate_metrics(hr_folder, sr_folder):
    ssim_values = []

    # Get lists of image files in both folders
    hr_images = [f for f in os.listdir(hr_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]
    sr_images = [f for f in os.listdir(sr_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]

    # Ensure both folders have the same number of images
    if len(hr_images) != len(sr_images):
        raise ValueError("The number of images in HR and SR folders must be the same.")

    # Loop through each image pair
    for i in range(len(hr_images)):
        hr_image_path = os.path.join(hr_folder, hr_images[i])
        sr_image_path = os.path.join(sr_folder, sr_images[i])

        # Read HR and SR images
        hr_image = cv2.imread(hr_image_path)
        sr_image = cv2.imread(sr_image_path)

        # Calculate SSIM
        ssim_value = calculate_ssim(hr_image, sr_image)
        ssim_values.append(ssim_value)

        # Display the SSIM value for the current image pair
        print(f'Image: {hr_images[i]} | SSIM: {ssim_value:.4f}')

    # Calculate average SSIM
    average_ssim = np.mean(ssim_values)
    print(f'Average SSIM: {average_ssim:.4f}')

# Example usage
hr_folder = 'ORIGINAL_X3'  # Replace with your HR folder path
sr_folder = 'WAZIR_PAN_X3'   # Replace with your SR folder path
calculate_metrics(hr_folder, sr_folder)



import os
import cv2
import matplotlib.pyplot as plt

def plot_images(hr_folder, sr_folder):
    # Get lists of image files in both folders
    hr_images = [f for f in os.listdir(hr_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]
    sr_images = [f for f in os.listdir(sr_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]

    # Ensure both folders have the same number of images
    if len(hr_images) != len(sr_images):
        raise ValueError("The number of images in HR and SR folders must be the same.")

    # Set up the plot
    num_images = len(hr_images)
    plt.figure(figsize=(15, 5 * num_images))

    # Loop through each image pair
    for i in range(num_images):
        hr_image_path = os.path.join(hr_folder, hr_images[i])
        sr_image_path = os.path.join(sr_folder, sr_images[i])

        # Read images
        hr_image = cv2.imread(hr_image_path)
        sr_image = cv2.imread(sr_image_path)

        # Convert BGR to RGB (OpenCV loads images in BGR format)
        hr_image = cv2.cvtColor(hr_image, cv2.COLOR_BGR2RGB)
        sr_image = cv2.cvtColor(sr_image, cv2.COLOR_BGR2RGB)

        # Plot HR image
        plt.subplot(num_images, 2, 2 * i + 1)
        plt.imshow(hr_image)
        plt.title(f'High Resolution - {hr_images[i]}')
        plt.axis('off')

        # Plot SR image
        plt.subplot(num_images, 2, 2 * i + 2)
        plt.imshow(sr_image)
        plt.title(f'Super Resolution - {sr_images[i]}')
        plt.axis('off')

    plt.tight_layout()
    plt.show()

# Example usage
hr_folder = 'ORIGINAL_X3'  # Replace with your HR folder path
sr_folder = 'WAZIR_PAN_X3'   # Replace with your SR folder path
plot_images(hr_folder, sr_folder)

# %%
from super_image import PanModel, ImageLoader
from PIL import Image
import requests

def process_images(input_folder, output_folder, model_name='eugenesiow/pan', scale=4):
    # Load the pre-trained model
    model = PanModel.from_pretrained(model_name, scale=scale)

    # Ensure the output folder exists
    #os.makedirs(output_folder, exist_ok=True)

    # Iterate through all images in the input folder
    for filename in os.listdir(input_folder):
        if filename.endswith(('.png', '.jpg', '.jpeg')):  # Check for image file extensions
            # Load the image
            image_path = os.path.join(input_folder, filename)
            print(f'Processing {image_path}...')
            image = Image.open(image_path)

            # Prepare the image for the model
            inputs = ImageLoader.load_image(image)

            # Perform super-resolution
            preds = model(inputs)

            # Save the output image
            output_path = os.path.join(output_folder, f'scaled_{filename}')
            ImageLoader.save_image(preds, output_path)
            print(f'Saved scaled image to {output_path}')

# Example usage
input_folder = 'LR_X4'  # Replace with your input folder path
output_folder = 'WAZIR_PAN_X4'  # Replace with your output folder path
process_images(input_folder, output_folder)


import os
import cv2
import numpy as np

def calculate_psnr(reference, distorted):
    """Calculate PSNR between two images."""
    mse = np.mean((reference - distorted) ** 2)
    if mse == 0:
        return float('inf')  # If MSE is zero, PSNR is infinite
    max_pixel_value = 255.0  # For 8-bit images
    psnr = 20 * np.log10(max_pixel_value / np.sqrt(mse))
    return psnr

def calculate_metrics(hr_folder, sr_folder):
    psnr_values = []

    # Get lists of image files in both folders
    hr_images = [f for f in os.listdir(hr_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]
    sr_images = [f for f in os.listdir(sr_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]

    # Ensure both folders have the same number of images
    if len(hr_images) != len(sr_images):
        raise ValueError("The number of images in HR and SR folders must be the same.")

    # Loop through each image pair
    for i in range(len(hr_images)):
        hr_image_path = os.path.join(hr_folder, hr_images[i])
        sr_image_path = os.path.join(sr_folder, sr_images[i])

        # Read HR and SR images
        hr_image = cv2.imread(hr_image_path)
        sr_image = cv2.imread(sr_image_path)

        # Calculate PSNR
        psnr_value = calculate_psnr(hr_image, sr_image)
        psnr_values.append(psnr_value)

        # Display the PSNR value for the current image pair
        print(f'Image: {hr_images[i]} | PSNR: {psnr_value:.4f} dB')

    # Calculate average PSNR
    average_psnr = np.mean(psnr_values)
    print(f'Average PSNR: {average_psnr:.4f} dB')

# Example usage
hr_folder = 'ORIGINAL_X4'  # Replace with your HR folder path
sr_folder = 'WAZIR_PAN_X4'   # Replace with your SR folder path
calculate_metrics(hr_folder, sr_folder)


#############################################SSIM##########################
import os
import cv2
import numpy as np
from skimage.metrics import structural_similarity as ssim

def calculate_ssim(reference, distorted):
    """Calculate SSIM between two images."""
    if reference.shape != distorted.shape:
        raise ValueError("Reference and distorted images must have the same dimensions.")
    
    # Convert images to grayscale if they are not already
    if len(reference.shape) == 3:
        reference = cv2.cvtColor(reference, cv2.COLOR_BGR2GRAY)
    if len(distorted.shape) == 3:
        distorted = cv2.cvtColor(distorted, cv2.COLOR_BGR2GRAY)

    return ssim(reference, distorted)

def calculate_metrics(hr_folder, sr_folder):
    ssim_values = []

    # Get lists of image files in both folders
    hr_images = [f for f in os.listdir(hr_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]
    sr_images = [f for f in os.listdir(sr_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]

    # Ensure both folders have the same number of images
    if len(hr_images) != len(sr_images):
        raise ValueError("The number of images in HR and SR folders must be the same.")

    # Loop through each image pair
    for i in range(len(hr_images)):
        hr_image_path = os.path.join(hr_folder, hr_images[i])
        sr_image_path = os.path.join(sr_folder, sr_images[i])

        # Read HR and SR images
        hr_image = cv2.imread(hr_image_path)
        sr_image = cv2.imread(sr_image_path)

        # Calculate SSIM
        ssim_value = calculate_ssim(hr_image, sr_image)
        ssim_values.append(ssim_value)

        # Display the SSIM value for the current image pair
        print(f'Image: {hr_images[i]} | SSIM: {ssim_value:.4f}')

    # Calculate average SSIM
    average_ssim = np.mean(ssim_values)
    print(f'Average SSIM: {average_ssim:.4f}')

# Example usage
hr_folder = 'ORIGINAL_X4'  # Replace with your HR folder path
sr_folder = 'WAZIR_PAN_X4'   # Replace with your SR folder path
calculate_metrics(hr_folder, sr_folder)



import os
import cv2
import matplotlib.pyplot as plt

def plot_images(hr_folder, sr_folder):
    # Get lists of image files in both folders
    hr_images = [f for f in os.listdir(hr_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]
    sr_images = [f for f in os.listdir(sr_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]

    # Ensure both folders have the same number of images
    if len(hr_images) != len(sr_images):
        raise ValueError("The number of images in HR and SR folders must be the same.")

    # Set up the plot
    num_images = len(hr_images)
    plt.figure(figsize=(15, 5 * num_images))

    # Loop through each image pair
    for i in range(num_images):
        hr_image_path = os.path.join(hr_folder, hr_images[i])
        sr_image_path = os.path.join(sr_folder, sr_images[i])

        # Read images
        hr_image = cv2.imread(hr_image_path)
        sr_image = cv2.imread(sr_image_path)

        # Convert BGR to RGB (OpenCV loads images in BGR format)
        hr_image = cv2.cvtColor(hr_image, cv2.COLOR_BGR2RGB)
        sr_image = cv2.cvtColor(sr_image, cv2.COLOR_BGR2RGB)

        # Plot HR image
        plt.subplot(num_images, 2, 2 * i + 1)
        plt.imshow(hr_image)
        plt.title(f'High Resolution - {hr_images[i]}')
        plt.axis('off')

        # Plot SR image
        plt.subplot(num_images, 2, 2 * i + 2)
        plt.imshow(sr_image)
        plt.title(f'Super Resolution - {sr_images[i]}')
        plt.axis('off')

    plt.tight_layout()
    plt.show()

# Example usage
hr_folder = 'ORIGINAL_X4'  # Replace with your HR folder path
sr_folder = 'WAZIR_PAN_X4'   # Replace with your SR folder path
plot_images(hr_folder, sr_folder)

# %%
###################### DRLN METHOD ######################

# %%
# !mkdir WAZIR_DRLN_X2
# !mkdir WAZIR_DRLN_X3
# !mkdir WAZIR_DRLN_X4

# %%
from super_image import DrlnModel, ImageLoader
from PIL import Image
import requests

def process_images(input_folder, output_folder, model_name='eugenesiow/drln', scale=2):
    # Load the pre-trained model
    model = DrlnModel.from_pretrained(model_name, scale=scale)

    # Ensure the output folder exists
    #os.makedirs(output_folder, exist_ok=True)

    # Iterate through all images in the input folder
    for filename in os.listdir(input_folder):
        if filename.endswith(('.png', '.jpg', '.jpeg')):  # Check for image file extensions
            # Load the image
            image_path = os.path.join(input_folder, filename)
            print(f'Processing {image_path}...')
            image = Image.open(image_path)

            # Prepare the image for the model
            inputs = ImageLoader.load_image(image)

            # Perform super-resolution
            preds = model(inputs)

            # Save the output image
            output_path = os.path.join(output_folder, f'scaled_{filename}')
            ImageLoader.save_image(preds, output_path)
            print(f'Saved scaled image to {output_path}')

# Example usage
input_folder = 'LR_X2'  # Replace with your input folder path
output_folder = 'WAZIR_DRLN_X2'  # Replace with your output folder path
process_images(input_folder, output_folder)


import os
import cv2
import numpy as np

def calculate_psnr(reference, distorted):
    """Calculate PSNR between two images."""
    mse = np.mean((reference - distorted) ** 2)
    if mse == 0:
        return float('inf')  # If MSE is zero, PSNR is infinite
    max_pixel_value = 255.0  # For 8-bit images
    psnr = 20 * np.log10(max_pixel_value / np.sqrt(mse))
    return psnr

def calculate_metrics(hr_folder, sr_folder):
    psnr_values = []

    # Get lists of image files in both folders
    hr_images = [f for f in os.listdir(hr_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]
    sr_images = [f for f in os.listdir(sr_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]

    # Ensure both folders have the same number of images
    if len(hr_images) != len(sr_images):
        raise ValueError("The number of images in HR and SR folders must be the same.")

    # Loop through each image pair
    for i in range(len(hr_images)):
        hr_image_path = os.path.join(hr_folder, hr_images[i])
        sr_image_path = os.path.join(sr_folder, sr_images[i])

        # Read HR and SR images
        hr_image = cv2.imread(hr_image_path)
        sr_image = cv2.imread(sr_image_path)

        # Calculate PSNR
        psnr_value = calculate_psnr(hr_image, sr_image)
        psnr_values.append(psnr_value)

        # Display the PSNR value for the current image pair
        print(f'Image: {hr_images[i]} | PSNR: {psnr_value:.4f} dB')

    # Calculate average PSNR
    average_psnr = np.mean(psnr_values)
    print(f'Average PSNR: {average_psnr:.4f} dB')

# Example usage
hr_folder = 'ORIGINAL_X2'  # Replace with your HR folder path
sr_folder = 'WAZIR_DRLN_X2'   # Replace with your SR folder path
calculate_metrics(hr_folder, sr_folder)


#############################################SSIM##########################
import os
import cv2
import numpy as np
from skimage.metrics import structural_similarity as ssim

def calculate_ssim(reference, distorted):
    """Calculate SSIM between two images."""
    if reference.shape != distorted.shape:
        raise ValueError("Reference and distorted images must have the same dimensions.")
    
    # Convert images to grayscale if they are not already
    if len(reference.shape) == 3:
        reference = cv2.cvtColor(reference, cv2.COLOR_BGR2GRAY)
    if len(distorted.shape) == 3:
        distorted = cv2.cvtColor(distorted, cv2.COLOR_BGR2GRAY)

    return ssim(reference, distorted)

def calculate_metrics(hr_folder, sr_folder):
    ssim_values = []

    # Get lists of image files in both folders
    hr_images = [f for f in os.listdir(hr_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]
    sr_images = [f for f in os.listdir(sr_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]

    # Ensure both folders have the same number of images
    if len(hr_images) != len(sr_images):
        raise ValueError("The number of images in HR and SR folders must be the same.")

    # Loop through each image pair
    for i in range(len(hr_images)):
        hr_image_path = os.path.join(hr_folder, hr_images[i])
        sr_image_path = os.path.join(sr_folder, sr_images[i])

        # Read HR and SR images
        hr_image = cv2.imread(hr_image_path)
        sr_image = cv2.imread(sr_image_path)

        # Calculate SSIM
        ssim_value = calculate_ssim(hr_image, sr_image)
        ssim_values.append(ssim_value)

        # Display the SSIM value for the current image pair
        print(f'Image: {hr_images[i]} | SSIM: {ssim_value:.4f}')

    # Calculate average SSIM
    average_ssim = np.mean(ssim_values)
    print(f'Average SSIM: {average_ssim:.4f}')

# Example usage
hr_folder = 'ORIGINAL_X2'  # Replace with your HR folder path
sr_folder = 'WAZIR_DRLN_X2'   # Replace with your SR folder path
calculate_metrics(hr_folder, sr_folder)



import os
import cv2
import matplotlib.pyplot as plt

def plot_images(hr_folder, sr_folder):
    # Get lists of image files in both folders
    hr_images = [f for f in os.listdir(hr_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]
    sr_images = [f for f in os.listdir(sr_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]

    # Ensure both folders have the same number of images
    if len(hr_images) != len(sr_images):
        raise ValueError("The number of images in HR and SR folders must be the same.")

    # Set up the plot
    num_images = len(hr_images)
    plt.figure(figsize=(15, 5 * num_images))

    # Loop through each image pair
    for i in range(num_images):
        hr_image_path = os.path.join(hr_folder, hr_images[i])
        sr_image_path = os.path.join(sr_folder, sr_images[i])

        # Read images
        hr_image = cv2.imread(hr_image_path)
        sr_image = cv2.imread(sr_image_path)

        # Convert BGR to RGB (OpenCV loads images in BGR format)
        hr_image = cv2.cvtColor(hr_image, cv2.COLOR_BGR2RGB)
        sr_image = cv2.cvtColor(sr_image, cv2.COLOR_BGR2RGB)

        # Plot HR image
        plt.subplot(num_images, 2, 2 * i + 1)
        plt.imshow(hr_image)
        plt.title(f'High Resolution - {hr_images[i]}')
        plt.axis('off')

        # Plot SR image
        plt.subplot(num_images, 2, 2 * i + 2)
        plt.imshow(sr_image)
        plt.title(f'Super Resolution - {sr_images[i]}')
        plt.axis('off')

    plt.tight_layout()
    plt.show()

# Example usage
hr_folder = 'ORIGINAL_X2'  # Replace with your HR folder path
sr_folder = 'WAZIR_DRLN_X2'   # Replace with your SR folder path
plot_images(hr_folder, sr_folder)

# %%
########################### DRLN SCALE 3X #########################

# %%
from super_image import DrlnModel, ImageLoader
from PIL import Image
import requests

def process_images(input_folder, output_folder, model_name='eugenesiow/drln', scale=3):
    # Load the pre-trained model
    model = DrlnModel.from_pretrained(model_name, scale=scale)

    # Ensure the output folder exists
    #os.makedirs(output_folder, exist_ok=True)

    # Iterate through all images in the input folder
    for filename in os.listdir(input_folder):
        if filename.endswith(('.png', '.jpg', '.jpeg')):  # Check for image file extensions
            # Load the image
            image_path = os.path.join(input_folder, filename)
            print(f'Processing {image_path}...')
            image = Image.open(image_path)

            # Prepare the image for the model
            inputs = ImageLoader.load_image(image)

            # Perform super-resolution
            preds = model(inputs)

            # Save the output image
            output_path = os.path.join(output_folder, f'scaled_{filename}')
            ImageLoader.save_image(preds, output_path)
            print(f'Saved scaled image to {output_path}')

# Example usage
input_folder = 'LR_X3'  # Replace with your input folder path
output_folder = 'WAZIR_DRLN_X3'  # Replace with your output folder path
process_images(input_folder, output_folder)


import os
import cv2
import numpy as np

def calculate_psnr(reference, distorted):
    """Calculate PSNR between two images."""
    mse = np.mean((reference - distorted) ** 2)
    if mse == 0:
        return float('inf')  # If MSE is zero, PSNR is infinite
    max_pixel_value = 255.0  # For 8-bit images
    psnr = 20 * np.log10(max_pixel_value / np.sqrt(mse))
    return psnr

def calculate_metrics(hr_folder, sr_folder):
    psnr_values = []

    # Get lists of image files in both folders
    hr_images = [f for f in os.listdir(hr_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]
    sr_images = [f for f in os.listdir(sr_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]

    # Ensure both folders have the same number of images
    if len(hr_images) != len(sr_images):
        raise ValueError("The number of images in HR and SR folders must be the same.")

    # Loop through each image pair
    for i in range(len(hr_images)):
        hr_image_path = os.path.join(hr_folder, hr_images[i])
        sr_image_path = os.path.join(sr_folder, sr_images[i])

        # Read HR and SR images
        hr_image = cv2.imread(hr_image_path)
        sr_image = cv2.imread(sr_image_path)

        # Calculate PSNR
        psnr_value = calculate_psnr(hr_image, sr_image)
        psnr_values.append(psnr_value)

        # Display the PSNR value for the current image pair
        print(f'Image: {hr_images[i]} | PSNR: {psnr_value:.4f} dB')

    # Calculate average PSNR
    average_psnr = np.mean(psnr_values)
    print(f'Average PSNR: {average_psnr:.4f} dB')

# Example usage
hr_folder = 'ORIGINAL_X3'  # Replace with your HR folder path
sr_folder = 'WAZIR_DRLN_X3'   # Replace with your SR folder path
calculate_metrics(hr_folder, sr_folder)


#############################################SSIM##########################
import os
import cv2
import numpy as np
from skimage.metrics import structural_similarity as ssim

def calculate_ssim(reference, distorted):
    """Calculate SSIM between two images."""
    if reference.shape != distorted.shape:
        raise ValueError("Reference and distorted images must have the same dimensions.")
    
    # Convert images to grayscale if they are not already
    if len(reference.shape) == 3:
        reference = cv2.cvtColor(reference, cv2.COLOR_BGR2GRAY)
    if len(distorted.shape) == 3:
        distorted = cv2.cvtColor(distorted, cv2.COLOR_BGR2GRAY)

    return ssim(reference, distorted)

def calculate_metrics(hr_folder, sr_folder):
    ssim_values = []

    # Get lists of image files in both folders
    hr_images = [f for f in os.listdir(hr_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]
    sr_images = [f for f in os.listdir(sr_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]

    # Ensure both folders have the same number of images
    if len(hr_images) != len(sr_images):
        raise ValueError("The number of images in HR and SR folders must be the same.")

    # Loop through each image pair
    for i in range(len(hr_images)):
        hr_image_path = os.path.join(hr_folder, hr_images[i])
        sr_image_path = os.path.join(sr_folder, sr_images[i])

        # Read HR and SR images
        hr_image = cv2.imread(hr_image_path)
        sr_image = cv2.imread(sr_image_path)

        # Calculate SSIM
        ssim_value = calculate_ssim(hr_image, sr_image)
        ssim_values.append(ssim_value)

        # Display the SSIM value for the current image pair
        print(f'Image: {hr_images[i]} | SSIM: {ssim_value:.4f}')

    # Calculate average SSIM
    average_ssim = np.mean(ssim_values)
    print(f'Average SSIM: {average_ssim:.4f}')

# Example usage
hr_folder = 'ORIGINAL_X3'  # Replace with your HR folder path
sr_folder = 'WAZIR_DRLN_X3'   # Replace with your SR folder path
calculate_metrics(hr_folder, sr_folder)



import os
import cv2
import matplotlib.pyplot as plt

def plot_images(hr_folder, sr_folder):
    # Get lists of image files in both folders
    hr_images = [f for f in os.listdir(hr_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]
    sr_images = [f for f in os.listdir(sr_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]

    # Ensure both folders have the same number of images
    if len(hr_images) != len(sr_images):
        raise ValueError("The number of images in HR and SR folders must be the same.")

    # Set up the plot
    num_images = len(hr_images)
    plt.figure(figsize=(15, 5 * num_images))

    # Loop through each image pair
    for i in range(num_images):
        hr_image_path = os.path.join(hr_folder, hr_images[i])
        sr_image_path = os.path.join(sr_folder, sr_images[i])

        # Read images
        hr_image = cv2.imread(hr_image_path)
        sr_image = cv2.imread(sr_image_path)

        # Convert BGR to RGB (OpenCV loads images in BGR format)
        hr_image = cv2.cvtColor(hr_image, cv2.COLOR_BGR2RGB)
        sr_image = cv2.cvtColor(sr_image, cv2.COLOR_BGR2RGB)

        # Plot HR image
        plt.subplot(num_images, 2, 2 * i + 1)
        plt.imshow(hr_image)
        plt.title(f'High Resolution - {hr_images[i]}')
        plt.axis('off')

        # Plot SR image
        plt.subplot(num_images, 2, 2 * i + 2)
        plt.imshow(sr_image)
        plt.title(f'Super Resolution - {sr_images[i]}')
        plt.axis('off')

    plt.tight_layout()
    plt.show()

# Example usage
hr_folder = 'ORIGINAL_X3'  # Replace with your HR folder path
sr_folder = 'WAZIR_DRLN_X3'   # Replace with your SR folder path
plot_images(hr_folder, sr_folder)

# %%
################### DRLN SCALE 4X #####################

# %%
from super_image import DrlnModel, ImageLoader
from PIL import Image
import requests

def process_images(input_folder, output_folder, model_name='eugenesiow/drln', scale=4):
    # Load the pre-trained model
    model = DrlnModel.from_pretrained(model_name, scale=scale)

    # Ensure the output folder exists
    #os.makedirs(output_folder, exist_ok=True)

    # Iterate through all images in the input folder
    for filename in os.listdir(input_folder):
        if filename.endswith(('.png', '.jpg', '.jpeg')):  # Check for image file extensions
            # Load the image
            image_path = os.path.join(input_folder, filename)
            print(f'Processing {image_path}...')
            image = Image.open(image_path)

            # Prepare the image for the model
            inputs = ImageLoader.load_image(image)

            # Perform super-resolution
            preds = model(inputs)

            # Save the output image
            output_path = os.path.join(output_folder, f'scaled_{filename}')
            ImageLoader.save_image(preds, output_path)
            print(f'Saved scaled image to {output_path}')

# Example usage
input_folder = 'LR_X4'  # Replace with your input folder path
output_folder = 'WAZIR_DRLN_X4'  # Replace with your output folder path
process_images(input_folder, output_folder)


import os
import cv2
import numpy as np

def calculate_psnr(reference, distorted):
    """Calculate PSNR between two images."""
    mse = np.mean((reference - distorted) ** 2)
    if mse == 0:
        return float('inf')  # If MSE is zero, PSNR is infinite
    max_pixel_value = 255.0  # For 8-bit images
    psnr = 20 * np.log10(max_pixel_value / np.sqrt(mse))
    return psnr

def calculate_metrics(hr_folder, sr_folder):
    psnr_values = []

    # Get lists of image files in both folders
    hr_images = [f for f in os.listdir(hr_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]
    sr_images = [f for f in os.listdir(sr_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]

    # Ensure both folders have the same number of images
    if len(hr_images) != len(sr_images):
        raise ValueError("The number of images in HR and SR folders must be the same.")

    # Loop through each image pair
    for i in range(len(hr_images)):
        hr_image_path = os.path.join(hr_folder, hr_images[i])
        sr_image_path = os.path.join(sr_folder, sr_images[i])

        # Read HR and SR images
        hr_image = cv2.imread(hr_image_path)
        sr_image = cv2.imread(sr_image_path)

        # Calculate PSNR
        psnr_value = calculate_psnr(hr_image, sr_image)
        psnr_values.append(psnr_value)

        # Display the PSNR value for the current image pair
        print(f'Image: {hr_images[i]} | PSNR: {psnr_value:.4f} dB')

    # Calculate average PSNR
    average_psnr = np.mean(psnr_values)
    print(f'Average PSNR: {average_psnr:.4f} dB')

# Example usage
hr_folder = 'ORIGINAL_X4'  # Replace with your HR folder path
sr_folder = 'WAZIR_DRLN_X4'   # Replace with your SR folder path
calculate_metrics(hr_folder, sr_folder)





#############################################SSIM##########################
import os
import cv2
import numpy as np
from skimage.metrics import structural_similarity as ssim

def calculate_ssim(reference, distorted):
    """Calculate SSIM between two images."""
    if reference.shape != distorted.shape:
        raise ValueError("Reference and distorted images must have the same dimensions.")
    
    # Convert images to grayscale if they are not already
    if len(reference.shape) == 3:
        reference = cv2.cvtColor(reference, cv2.COLOR_BGR2GRAY)
    if len(distorted.shape) == 3:
        distorted = cv2.cvtColor(distorted, cv2.COLOR_BGR2GRAY)

    return ssim(reference, distorted)

def calculate_metrics(hr_folder, sr_folder):
    ssim_values = []

    # Get lists of image files in both folders
    hr_images = [f for f in os.listdir(hr_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]
    sr_images = [f for f in os.listdir(sr_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]

    # Ensure both folders have the same number of images
    if len(hr_images) != len(sr_images):
        raise ValueError("The number of images in HR and SR folders must be the same.")

    # Loop through each image pair
    for i in range(len(hr_images)):
        hr_image_path = os.path.join(hr_folder, hr_images[i])
        sr_image_path = os.path.join(sr_folder, sr_images[i])

        # Read HR and SR images
        hr_image = cv2.imread(hr_image_path)
        sr_image = cv2.imread(sr_image_path)

        # Calculate SSIM
        ssim_value = calculate_ssim(hr_image, sr_image)
        ssim_values.append(ssim_value)

        # Display the SSIM value for the current image pair
        print(f'Image: {hr_images[i]} | SSIM: {ssim_value:.4f}')

    # Calculate average SSIM
    average_ssim = np.mean(ssim_values)
    print(f'Average SSIM: {average_ssim:.4f}')

# Example usage
hr_folder = 'ORIGINAL_X4'  # Replace with your HR folder path
sr_folder = 'WAZIR_DRLN_X4'   # Replace with your SR folder path
calculate_metrics(hr_folder, sr_folder)

import os
import cv2
import matplotlib.pyplot as plt

def plot_images(hr_folder, sr_folder):
    # Get lists of image files in both folders
    hr_images = [f for f in os.listdir(hr_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]
    sr_images = [f for f in os.listdir(sr_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]

    # Ensure both folders have the same number of images
    if len(hr_images) != len(sr_images):
        raise ValueError("The number of images in HR and SR folders must be the same.")

    # Set up the plot
    num_images = len(hr_images)
    plt.figure(figsize=(15, 5 * num_images))

    # Loop through each image pair
    for i in range(num_images):
        hr_image_path = os.path.join(hr_folder, hr_images[i])
        sr_image_path = os.path.join(sr_folder, sr_images[i])

        # Read images
        hr_image = cv2.imread(hr_image_path)
        sr_image = cv2.imread(sr_image_path)

        # Convert BGR to RGB (OpenCV loads images in BGR format)
        hr_image = cv2.cvtColor(hr_image, cv2.COLOR_BGR2RGB)
        sr_image = cv2.cvtColor(sr_image, cv2.COLOR_BGR2RGB)

        # Plot HR image
        plt.subplot(num_images, 2, 2 * i + 1)
        plt.imshow(hr_image)
        plt.title(f'High Resolution - {hr_images[i]}')
        plt.axis('off')

        # Plot SR image
        plt.subplot(num_images, 2, 2 * i + 2)
        plt.imshow(sr_image)
        plt.title(f'Super Resolution - {sr_images[i]}')
        plt.axis('off')

    plt.tight_layout()
    plt.show()

# Example usage
hr_folder = 'ORIGINAL_X4'  # Replace with your HR folder path
sr_folder = 'WAZIR_DRLN_X4'   # Replace with your SR folder path
plot_images(hr_folder, sr_folder)
