# %%
# !ls
# Out:
# sample_data

# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
# !wget http://vllab.ucmerced.edu/wlai24/LapSRN/results/Set5/x4/baby_x4_RFL.png
# Out:
# --2022-01-19 13:40:03--  http://vllab.ucmerced.edu/wlai24/LapSRN/results/Set5/x4/baby_x4_RFL.png
# Resolving vllab.ucmerced.edu (vllab.ucmerced.edu)... 169.236.184.69
# Connecting to vllab.ucmerced.edu (vllab.ucmerced.edu)|169.236.184.69|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 300107 (293K) [image/png]
# Saving to: ‘baby_x4_RFL.png’
#
# baby_x4_RFL.png     100%[===================>] 293.07K   477KB/s    in 0.6s
#
# 2022-01-19 13:40:04 (477 KB/s) - ‘baby_x4_RFL.png’ saved [300107/300107]

# %%
# !ls
# Out:
# baby_x4_RFL.png  sample_data

# %%
img = cv2.imread('baby_x4_RFL.png', cv2.IMREAD_UNCHANGED)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FC2C3093C90>

# %%
# !wget http://vllab.ucmerced.edu/wlai24/LapSRN/results/Set5/x4/baby_x4_bicubic.png
# Out:
# --2022-01-19 13:40:04--  http://vllab.ucmerced.edu/wlai24/LapSRN/results/Set5/x4/baby_x4_bicubic.png
# Resolving vllab.ucmerced.edu (vllab.ucmerced.edu)... 169.236.184.69
# Connecting to vllab.ucmerced.edu (vllab.ucmerced.edu)|169.236.184.69|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 256826 (251K) [image/png]
# Saving to: ‘baby_x4_bicubic.png’
#
# baby_x4_bicubic.png 100%[===================>] 250.81K   467KB/s    in 0.5s
#
# 2022-01-19 13:40:05 (467 KB/s) - ‘baby_x4_bicubic.png’ saved [256826/256826]

# %%
img = cv2.imread('baby_x4_bicubic.png', cv2.IMREAD_UNCHANGED)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FC2C3022ED0>
