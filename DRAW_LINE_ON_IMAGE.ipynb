# %%
#UPLOAD IMAGE
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3314ccd6-eb3d-45a1-b7bd-f7a9a1b3e410" name="files[]" multiple disabled />
#      <output id="result-3314ccd6-eb3d-45a1-b7bd-f7a9a1b3e410">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving zebra.png to zebra (2).png

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('zebra.png')
img=cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)
ax.set_title("GT")
plt.grid(0)
plt.show()

# %%
plt.imshow(img)
plt.plot([500,100],[350,50],'r',linewidth=20) #500,100 on x-axis end = 500, start 100   AND ON Y-AXIS 350 ad other point on 50 AND r, c is COLORS AND 10 width of line
plt.grid(0)
plt.show()
