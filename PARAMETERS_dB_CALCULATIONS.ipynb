# %%
# !git clone https://github.com/niazwazir/TestImage.git
# Out:
# Cloning into 'TestImage'...
# remote: Enumerating objects: 51, done.
# remote: Counting objects: 100% (51/51), done.
# remote: Compressing objects: 100% (51/51), done.
# remote: Total 51 (delta 11), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (51/51), done.

# %%
from IPython.display import Image
Image('TestImage/Parameters.png')

# %%
from IPython.display import Image
Image('TestImage/ParametersdBCalculation.png')
